# %% [markdown]
# # ML Foreclosure Binary Classification - 2.5% sample data
#
#     target = zeroBalCode (set to object dtype)
#     Binary classification sets zeroBalCode to either "0" or "1" for the 7 possible outcomes
#
#     "0" = "Loan Success"
#         * 01 = Prepaid or Matured
#         * 06 = Repurchased
#         * 16 = Reperforming Loan Sale
#
#     "1" =  "Loan Failure" - Most likely loss of money (but not necessarily) one of below conditions:
#         * 02 = Third Party Sale
#         * 03 = Short Sale
#         * 09 = Deed-in-Lieu,REO
#         * 15 = Note Sale

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#!pip install pycaret
from imblearn.over_sampling import RandomOverSampler
from pycaret.classification import *
#from pycaret.regression import *
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importing the data - only use *.ML.csv files!!!
# If you have *.MLReady.csv then [click here](#MLReady)

# %%
df=pd.read_csv("data/FM_Acq_Perf_FMAC_EPOCH2_ML2_loanAge.csv")
df.head()
# Out:
#    Unnamed: 0            id origChannel  \
# 0     2307189  100012021911           C
# 1     2307190  100209956357           B
# 2     2307191  100250194205           R
# 3     2307192  100366856388           R
# 4     2307193  100392775700           C
#
#                                   sellerName  origIntRate  origUPB  \
# 0  JPMORGAN CHASE BANK, NATIONAL ASSOCIATION        4.375   417000
# 1                     WELLS FARGO BANK, N.A.        5.125   348000
# 2                                      OTHER        5.125    65000
# 3                                      OTHER        4.875    37000
# 4                      BANK OF AMERICA, N.A.        4.625   195000
#
#    origLoanTerm    origDate  origLTV  origCLTV  numBorrowers  \
# 0           180  2009-02-01     27.0      27.0           2.0
# 1           360  2009-02-01     87.0      87.0           1.0
# 2           360  2009-02-01     95.0      95.0           1.0
# 3           360  2009-02-01     55.0      55.0           1.0
# 4           360  2009-02-01     52.0      52.0           2.0
#
#    origDebtIncRatio loanPurp propState  zipCode  pMIperct  mortInsType  \
# 0              14.0        R        NJ       76       0.0          0.0
# 1              50.0        R        VT       51      25.0          1.0
# 2              17.0        P        IL      613      25.0          1.0
# 3              23.0        P        IL      626       0.0          0.0
# 4              54.0        C        NJ       82       0.0          0.0
#
#    bestCreditScore  worstCreditScore  avgCreditScore  loanAge    mSA  \
# 0            759.0             756.0           757.5       43  35620
# 1            689.0             689.0           689.0       90      0
# 2            738.0             738.0           738.0       38      0
# 3            777.0             777.0           777.0       48      0
# 4            810.0             703.0           756.5       69  12100
#
#    zeroBalCode  deliqGood  deliqBad  deliqMax  fmacRateMax  fmacRateMin  \
# 0          1.0         39         4       1.0         5.25         5.04
# 1          9.0         75        15       7.0         5.25         5.04
# 2          9.0         18        20      16.0         5.25         5.04
# 3          6.0         44         4       5.0         5.25         5.04
# 4          1.0         68         1       1.0         5.25         5.04
#
#    fmacRateAvg  fmacRateVolatility  fredRate  rateDiffAbove  rateDiffBelow  \
# 0         5.13            0.041667      2.87         -0.875          0.665
# 1         5.13            0.041667      2.87         -0.125         -0.085
# 2         5.13            0.041667      2.87         -0.125         -0.085
# 3         5.13            0.041667      2.87         -0.375          0.165
# 4         5.13            0.041667      2.87         -0.625          0.415
#
#    rateDiffAvg  rateDiffAbovePct  rateDiffBelowPct  rateDiffAvgPct
# 0       -0.755         -0.166667          0.131944       -0.147173
# 1       -0.005         -0.023810         -0.016865       -0.000975
# 2       -0.005         -0.023810         -0.016865       -0.000975
# 3       -0.255         -0.071429          0.032738       -0.049708
# 4       -0.505         -0.119048          0.082341       -0.098441

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240948 entries, 0 to 240947
# Data columns (total 37 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          240948 non-null  int64
#  1   id                  240948 non-null  int64
#  2   origChannel         240948 non-null  object
#  3   sellerName          240948 non-null  object
#  4   origIntRate         240948 non-null  float64
#  5   origUPB             240948 non-null  int64
#  6   origLoanTerm        240948 non-null  int64
#  7   origDate            240948 non-null  object
#  8   origLTV             240948 non-null  float64
#  9   origCLTV            240948 non-null  float64
#  10  numBorrowers        240948 non-null  float64
#  11  origDebtIncRatio    240948 non-null  float64
#  12  loanPurp            240948 non-null  object
#  13  propState           240948 non-null  object
#  14  zipCode             240948 non-null  int64
#  15  pMIperct            240948 non-null  float64
#  16  mortInsType         240948 non-null  float64
#  17  bestCreditScore     240948 non-null  float64
#  18  worstCreditScore    240948 non-null  float64
#  19  avgCreditScore      240948 non-null  float64
#  20  loanAge             240948 non-null  int64
#  21  mSA                 240948 non-null  int64
#  22  zeroBalCode         240948 non-null  float64
#  23  deliqGood           240948 non-null  int64
#  24  deliqBad            240948 non-null  int64
#  25  deliqMax            240948 non-null  float64
#  26  fmacRateMax         240948 non-null  float64
#  27  fmacRateMin         240948 non-null  float64
#  28  fmacRateAvg         240948 non-null  float64
#  29  fmacRateVolatility  240948 non-null  float64
#  30  fredRate            240948 non-null  float64
#  31  rateDiffAbove       240948 non-null  float64
#  32  rateDiffBelow       240948 non-null  float64
#  33  rateDiffAvg         240948 non-null  float64
#  34  rateDiffAbovePct    240948 non-null  float64
#  35  rateDiffBelowPct    240948 non-null  float64
#  36  rateDiffAvgPct      240948 non-null  float64
# dtypes: float64(23), int64(9), object(5)
# memory usage: 68.0+ MB

# %% [markdown]
# ## Remove columns not involved in 'Foreclosure or Not' query

# %%
df.drop(['Unnamed: 0','id','fredRate','deliqGood','deliqBad','deliqMax'],1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240948 entries, 0 to 240947
# Data columns (total 31 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   origChannel         240948 non-null  object
#  1   sellerName          240948 non-null  object
#  2   origIntRate         240948 non-null  float64
#  3   origUPB             240948 non-null  int64
#  4   origLoanTerm        240948 non-null  int64
#  5   origDate            240948 non-null  object
#  6   origLTV             240948 non-null  float64
#  7   origCLTV            240948 non-null  float64
#  8   numBorrowers        240948 non-null  float64
#  9   origDebtIncRatio    240948 non-null  float64
#  10  loanPurp            240948 non-null  object
#  11  propState           240948 non-null  object
#  12  zipCode             240948 non-null  int64
#  13  pMIperct            240948 non-null  float64
#  14  mortInsType         240948 non-null  float64
#  15  bestCreditScore     240948 non-null  float64
#  16  worstCreditScore    240948 non-null  float64
#  17  avgCreditScore      240948 non-null  float64
#  18  loanAge             240948 non-null  int64
#  19  mSA                 240948 non-null  int64
#  20  zeroBalCode         240948 non-null  float64
#  21  fmacRateMax         240948 non-null  float64
#  22  fmacRateMin         240948 non-null  float64
#  23  fmacRateAvg         240948 non-null  float64
#  24  fmacRateVolatility  240948 non-null  float64
#  25  rateDiffAbove       240948 non-null  float64
#  26  rateDiffBelow       240948 non-null  float64
#  27  rateDiffAvg         240948 non-null  float64
#  28  rateDiffAbovePct    240948 non-null  float64
#  29  rateDiffBelowPct    240948 non-null  float64
#  30  rateDiffAvgPct      240948 non-null  float64
# dtypes: float64(21), int64(5), object(5)
# memory usage: 57.0+ MB

# %% [markdown]
# ## Engineer originDate into Date features

# %%
df['origDate'] = pd.to_datetime(df['origDate'])

# %%
df['origYear'] = df['origDate'].dt.year
df['origMonth'] = df['origDate'].dt.month

# %%
df.drop(['origDate'],1,inplace=True)

# %%
df[['origYear','origMonth']].head()
# Out:
#    origYear  origMonth
# 0      2009          2
# 1      2009          2
# 2      2009          2
# 3      2009          2
# 4      2009          2

# %% [markdown]
# # Turn zero Balance Code Into binary "0" GOOD and "1" BAD

# %%
df.zeroBalCode.unique()
# Out:
# array([ 1.,  9.,  6., 15.,  3., 16.,  2.])

# %%
df['zeroBalCode'] = df.zeroBalCode.replace([1,6,16],0)
df['zeroBalCode'] = df.zeroBalCode.replace([9,3,2,15],1)

# %%
df.zeroBalCode.unique()
# Out:
# array([0., 1.])

# %%
#Checking datatypes of individual feature
df.head()
# Out:
#   origChannel                                 sellerName  origIntRate  \
# 0           C  JPMORGAN CHASE BANK, NATIONAL ASSOCIATION        4.375
# 1           B                     WELLS FARGO BANK, N.A.        5.125
# 2           R                                      OTHER        5.125
# 3           R                                      OTHER        4.875
# 4           C                      BANK OF AMERICA, N.A.        4.625
#
#    origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio  \
# 0   417000           180     27.0      27.0           2.0              14.0
# 1   348000           360     87.0      87.0           1.0              50.0
# 2    65000           360     95.0      95.0           1.0              17.0
# 3    37000           360     55.0      55.0           1.0              23.0
# 4   195000           360     52.0      52.0           2.0              54.0
#
#   loanPurp propState  zipCode  pMIperct  mortInsType  bestCreditScore  \
# 0        R        NJ       76       0.0          0.0            759.0
# 1        R        VT       51      25.0          1.0            689.0
# 2        P        IL      613      25.0          1.0            738.0
# 3        P        IL      626       0.0          0.0            777.0
# 4        C        NJ       82       0.0          0.0            810.0
#
#    worstCreditScore  avgCreditScore  loanAge    mSA  zeroBalCode  fmacRateMax  \
# 0             756.0           757.5       43  35620          0.0         5.25
# 1             689.0           689.0       90      0          1.0         5.25
# 2             738.0           738.0       38      0          1.0         5.25
# 3             777.0           777.0       48      0          0.0         5.25
# 4             703.0           756.5       69  12100          0.0         5.25
#
#    fmacRateMin  fmacRateAvg  fmacRateVolatility  rateDiffAbove  rateDiffBelow  \
# 0         5.04         5.13            0.041667         -0.875          0.665
# 1         5.04         5.13            0.041667         -0.125         -0.085
# 2         5.04         5.13            0.041667         -0.125         -0.085
# 3         5.04         5.13            0.041667         -0.375          0.165
# 4         5.04         5.13            0.041667         -0.625          0.415
#
#    rateDiffAvg  rateDiffAbovePct  rateDiffBelowPct  rateDiffAvgPct  origYear  \
# 0       -0.755         -0.166667          0.131944       -0.147173      2009
# 1       -0.005         -0.023810         -0.016865       -0.000975      2009
# 2       -0.005         -0.023810         -0.016865       -0.000975      2009
# 3       -0.255         -0.071429          0.032738       -0.049708      2009
# 4       -0.505         -0.119048          0.082341       -0.098441      2009
#
#    origMonth
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %% [markdown]
# # Review values for dates and slice (if needed) the timeframe you want

# %%
df.origYear.unique()
# Out:
# array([2009, 2010, 2011, 2012, 2013], dtype=int64)

# %%
df['origMonth'].unique()
# Out:
# array([ 2,  3,  5,  4,  6,  7,  8,  9, 10, 11, 12,  1], dtype=int64)

# %%
df.head()
# Out:
#   origChannel                                 sellerName  origIntRate  \
# 0           C  JPMORGAN CHASE BANK, NATIONAL ASSOCIATION        4.375
# 1           B                     WELLS FARGO BANK, N.A.        5.125
# 2           R                                      OTHER        5.125
# 3           R                                      OTHER        4.875
# 4           C                      BANK OF AMERICA, N.A.        4.625
#
#    origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio  \
# 0   417000           180     27.0      27.0           2.0              14.0
# 1   348000           360     87.0      87.0           1.0              50.0
# 2    65000           360     95.0      95.0           1.0              17.0
# 3    37000           360     55.0      55.0           1.0              23.0
# 4   195000           360     52.0      52.0           2.0              54.0
#
#   loanPurp propState  zipCode  pMIperct  mortInsType  bestCreditScore  \
# 0        R        NJ       76       0.0          0.0            759.0
# 1        R        VT       51      25.0          1.0            689.0
# 2        P        IL      613      25.0          1.0            738.0
# 3        P        IL      626       0.0          0.0            777.0
# 4        C        NJ       82       0.0          0.0            810.0
#
#    worstCreditScore  avgCreditScore  loanAge    mSA  zeroBalCode  fmacRateMax  \
# 0             756.0           757.5       43  35620          0.0         5.25
# 1             689.0           689.0       90      0          1.0         5.25
# 2             738.0           738.0       38      0          1.0         5.25
# 3             777.0           777.0       48      0          0.0         5.25
# 4             703.0           756.5       69  12100          0.0         5.25
#
#    fmacRateMin  fmacRateAvg  fmacRateVolatility  rateDiffAbove  rateDiffBelow  \
# 0         5.04         5.13            0.041667         -0.875          0.665
# 1         5.04         5.13            0.041667         -0.125         -0.085
# 2         5.04         5.13            0.041667         -0.125         -0.085
# 3         5.04         5.13            0.041667         -0.375          0.165
# 4         5.04         5.13            0.041667         -0.625          0.415
#
#    rateDiffAvg  rateDiffAbovePct  rateDiffBelowPct  rateDiffAvgPct  origYear  \
# 0       -0.755         -0.166667          0.131944       -0.147173      2009
# 1       -0.005         -0.023810         -0.016865       -0.000975      2009
# 2       -0.005         -0.023810         -0.016865       -0.000975      2009
# 3       -0.255         -0.071429          0.032738       -0.049708      2009
# 4       -0.505         -0.119048          0.082341       -0.098441      2009
#
#    origMonth
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %% [markdown]
# # Coerce the column dtype (int in this case)

# %%
df = df.astype({'origLTV':'int','numBorrowers':'int','origDebtIncRatio':'int',\
               'mortInsType':'int','bestCreditScore':'int','loanAge':'int',\
               'worstCreditScore':'int','avgCreditScore':'int','zeroBalCode':'int'})
#,'zeroBalCode':'int'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240948 entries, 0 to 240947
# Data columns (total 32 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   origChannel         240948 non-null  object
#  1   sellerName          240948 non-null  object
#  2   origIntRate         240948 non-null  float64
#  3   origUPB             240948 non-null  int64
#  4   origLoanTerm        240948 non-null  int64
#  5   origLTV             240948 non-null  int32
#  6   origCLTV            240948 non-null  float64
#  7   numBorrowers        240948 non-null  int32
#  8   origDebtIncRatio    240948 non-null  int32
#  9   loanPurp            240948 non-null  object
#  10  propState           240948 non-null  object
#  11  zipCode             240948 non-null  int64
#  12  pMIperct            240948 non-null  float64
#  13  mortInsType         240948 non-null  int32
#  14  bestCreditScore     240948 non-null  int32
#  15  worstCreditScore    240948 non-null  int32
#  16  avgCreditScore      240948 non-null  int32
#  17  loanAge             240948 non-null  int32
#  18  mSA                 240948 non-null  int64
#  19  zeroBalCode         240948 non-null  int32
#  20  fmacRateMax         240948 non-null  float64
#  21  fmacRateMin         240948 non-null  float64
#  22  fmacRateAvg         240948 non-null  float64
#  23  fmacRateVolatility  240948 non-null  float64
#  24  rateDiffAbove       240948 non-null  float64
#  25  rateDiffBelow       240948 non-null  float64
#  26  rateDiffAvg         240948 non-null  float64
#  27  rateDiffAbovePct    240948 non-null  float64
#  28  rateDiffBelowPct    240948 non-null  float64
#  29  rateDiffAvgPct      240948 non-null  float64
#  30  origYear            240948 non-null  int64
#  31  origMonth           240948 non-null  int64
# dtypes: float64(13), int32(9), int64(6), object(4)
# memory usage: 50.6+ MB

# %% [markdown]
# <a id='MLReady'></a>

# %% [markdown]
# <a id='MLReady'></a>
# ## *MLReady.csv file loading point
# uncomment one of the boxes below

# %%
#df.to_csv('D:\FM_FULL_EPOCH2_MLReady.csv')

# %%
#df = pd.read_csv('D:\FM_FULL_EPOCH2_MLReady.csv')

# %% [markdown]
# # Oversampling (Since we are starting with only 6.3% of our predicted class)

# %%
good = df.zeroBalCode.value_counts()[0]
bad = df.zeroBalCode.value_counts()[1]
perct_bad = round(bad/(good + bad)*100,2)
print(f'We have {perct_bad}% Foreclosures in our dataset')
# Out:
# We have 8.96% Foreclosures in our dataset

# %%
from sklearn.model_selection import train_test_split

training_features, test_features, \
training_target, test_target, = train_test_split(
    df.drop(['zeroBalCode'], axis=1)
    , df['zeroBalCode']
    , test_size = .1
    , random_state=12
)

# %%
# Further split the training data into training/test
x_train, x_val, y_train, y_val = train_test_split(
    training_features
    , training_target
    , test_size = .1
    ,random_state=12
)

# %%
# For the training data, randomly sample 
ros = RandomOverSampler(sampling_strategy='minority')
x_train_res, y_train_res = ros.fit_sample(x_train, y_train)

# %%
print('#############################################')
print('Before oversampling: "Closed" crushes "Default" and causes issues:')
print(training_target.value_counts())
print('')
print('Before oversampling: "Closed" and "Default" are equal')
print(y_train_res.value_counts())
# Out:
# #############################################
# Before oversampling: "Closed" crushes "Default" and causes issues:
# 0    197398
# 1     19455
# Name: zeroBalCode, dtype: int64
#
# Before oversampling: "Closed" and "Default" are equal
# 1    177641
# 0    177641
# Name: zeroBalCode, dtype: int64

# %% [markdown]
# # Recombine X_train_res, y_train_res so PyCaret can deal with one df

# %%
y_train_res.shape
# Out:
# (355282,)

# %%
df = x_train_res.copy()

# %%
df['zeroBalCode'] = y_train_res

# %%
df.shape
# Out:
# (355282, 32)

# %% [markdown]
# # Review metrics last time before run (to have record of starting values)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355282 entries, 0 to 355281
# Data columns (total 32 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   origChannel         355282 non-null  object
#  1   sellerName          355282 non-null  object
#  2   origIntRate         355282 non-null  float64
#  3   origUPB             355282 non-null  int64
#  4   origLoanTerm        355282 non-null  int64
#  5   origLTV             355282 non-null  int32
#  6   origCLTV            355282 non-null  float64
#  7   numBorrowers        355282 non-null  int32
#  8   origDebtIncRatio    355282 non-null  int32
#  9   loanPurp            355282 non-null  object
#  10  propState           355282 non-null  object
#  11  zipCode             355282 non-null  int64
#  12  pMIperct            355282 non-null  float64
#  13  mortInsType         355282 non-null  int32
#  14  bestCreditScore     355282 non-null  int32
#  15  worstCreditScore    355282 non-null  int32
#  16  avgCreditScore      355282 non-null  int32
#  17  loanAge             355282 non-null  int32
#  18  mSA                 355282 non-null  int64
#  19  fmacRateMax         355282 non-null  float64
#  20  fmacRateMin         355282 non-null  float64
#  21  fmacRateAvg         355282 non-null  float64
#  22  fmacRateVolatility  355282 non-null  float64
#  23  rateDiffAbove       355282 non-null  float64
#  24  rateDiffBelow       355282 non-null  float64
#  25  rateDiffAvg         355282 non-null  float64
#  26  rateDiffAbovePct    355282 non-null  float64
#  27  rateDiffBelowPct    355282 non-null  float64
#  28  rateDiffAvgPct      355282 non-null  float64
#  29  origYear            355282 non-null  int64
#  30  origMonth           355282 non-null  int64
#  31  zeroBalCode         355282 non-null  int32
# dtypes: float64(13), int32(9), int64(6), object(4)
# memory usage: 74.5+ MB

# %%
df.head()
# Out:
#   origChannel                                 sellerName  origIntRate  \
# 0           B                                      OTHER        4.250
# 1           R                     WELLS FARGO BANK, N.A.        4.625
# 2           C  JPMORGAN CHASE BANK, NATIONAL ASSOCIATION        4.375
# 3           C                         GMAC MORTGAGE, LLC        4.375
# 4           R                     WELLS FARGO BANK, N.A.        4.250
#
#    origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio  \
# 0   178000           360       54      54.0             1                50
# 1    92000           180       80      80.0             1                38
# 2   163000           240       54      87.0             2                32
# 3   180000           360       80      80.0             1                36
# 4    53000           180       36      36.0             2                37
#
#   loanPurp propState  zipCode  pMIperct  mortInsType  bestCreditScore  \
# 0        C        MA       27       0.0            0              712
# 1        C        SC      298       0.0            0              763
# 2        R        CA      917       0.0            0              686
# 3        P        CA      946       0.0            0              777
# 4        R        NC      272       0.0            0              823
#
#    worstCreditScore  avgCreditScore  loanAge    mSA  fmacRateMax  fmacRateMin  \
# 0               712             712       84  39300         4.22         4.01
# 1               763             763       55  12260         4.58         4.54
# 2               666             676       42  31080         4.40         4.17
# 3               777             777       81  41860         5.14         4.71
# 4               798             810       44  24660         5.15         4.85
#
#    fmacRateAvg  fmacRateVolatility  rateDiffAbove  rateDiffBelow  rateDiffAvg  \
# 0       4.1060            0.052369          0.030         -0.240       0.1440
# 1       4.5640            0.008811          0.045         -0.085       0.0610
# 2       4.3000            0.055156         -0.025         -0.205       0.0750
# 3       4.9300            0.091295         -0.765          0.335      -0.5550
# 4       5.0025            0.061856         -0.900          0.600      -0.7525
#
#    rateDiffAbovePct  rateDiffBelowPct  rateDiffAvgPct  origYear  origMonth  \
# 0          0.007109         -0.059850        0.035071      2011          9
# 1          0.009825         -0.018722        0.013365      2010          7
# 2         -0.005682         -0.049161        0.017442      2010         11
# 3         -0.148833          0.071125       -0.112576      2009         12
# 4         -0.174757          0.123711       -0.150425      2009          3
#
#    zeroBalCode
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %% [markdown]
# # Pycaret - Setup with categorical definition

# %%
#model_setup = setup(df, target = 'zeroBalCode')

# %% [markdown]
# ### Use complex setup

# %%
model_setup = setup(
    df
    , target = 'zeroBalCode' # PyCaret will list this as "Label"
    , pca = False 
    , ignore_low_variance = True # Variance is calculated using the ratio of unique values to the number of samples, and the ratio of the most common value to the frequency of the second most common value.
    , normalize = True
    , ignore_features = None
    , handle_unknown_categorical = True
    , remove_outliers = True # outliers from the training data are removed using PCA linear dimensionality reduction using the Singular Value Decomposition technique.
#     , bin_numeric_features = [
#             'origIntRate'
#             , 'origUPB'
#             , 'origLTV'
#             , 'origDebtIncRatio'
#             , 'bestCreditScore'
#             , 'avgCreditScore'
#             , 'worstCreditScore'
#         ] # Set to True to bin numerics using K Means
    , feature_interaction = False
    , feature_selection = True
    , silent = True
    , profile = False
    , categorical_features = [
             'origYear'
            , 'origMonth'
            , 'mSA'
            , 'zipCode'
            , 'mortInsType'
            , 'origLoanTerm'
        ]
        , numeric_features = [
            'origIntRate'
            , 'numBorrowers'
            , 'origUPB'
            , 'origLTV'
            , 'origCLTV'
            , 'pMIperct'
            , 'loanAge'
            , 'origDebtIncRatio'
            , 'worstCreditScore'
            , 'bestCreditScore'
            , 'avgCreditScore'
            , 'rateDiffAbove'
            , 'rateDiffBelow'
            , 'rateDiffAvg'
            , 'rateDiffAbovePct'
            , 'rateDiffBelowPct'
            , 'rateDiffAvgPct'
            , 'fmacRateMax'
            , 'fmacRateMin'
            , 'fmacRateAvg'
            , 'fmacRateVolatility'
        ]
)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# #T_a6428758_f3c5_11ea_91fb_309c234564f5row15_col1,#T_a6428758_f3c5_11ea_91fb_309c234564f5row22_col1,#T_a6428758_f3c5_11ea_91fb_309c234564f5row26_col1,#T_a6428758_f3c5_11ea_91fb_309c234564f5row37_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_a6428758_f3c5_11ea_91fb_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a6428758_f3c5_11ea_91fb_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a6428758_f3c5_11ea_91fb_309c234564f5row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_a6428758_f3c5_11ea_91fb_309c234564f5row0_col1" class="data row0 col1" >4605</td>
#             </tr>
#             <tr>
#                         <th id="T_a6428758_f3c5_11ea_91fb_309c234564f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a6428758_f3c5_11ea_91fb_309c234564f5row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_a6428758_f3c5_11ea_91fb_309c234564f5row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_a6428758_f3c5_11ea_91fb_309c234564f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a6428758_f3c5_11ea_91fb_309c234564f5row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_a6428758_f3c5_11ea_91fb_309c234564f5row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_a6428758_f3c5_11ea_91fb_309c234564f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a6428758_f3c5_11ea_91fb_309c234564f5row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_a6428758_f3c5_11ea_91fb_309c234564f5row3_col1" class="data row3 col1" >(355282, 32)</td>
#             </tr>
#             <tr>
#                         <th id="T_a6428758_f3c5_11ea_91fb_309c234564f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_
" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61350528_f41b_11ea_aa96_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_61350528_f41b_11ea_aa96_309c234564f5row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#                         <td id="T_61350528_f41b_11ea_aa96_309c234564f5row0_col1" class="data row0 col1" >0.9948</td>
#                         <td id="T_61350528_f41b_11ea_aa96_309c234564f5row0_col2" class="data row0 col2" >0.9997</td>
#                         <td id="T_61350528_f41b_11ea_aa96_309c234564f5row0_col3" class="data row0 col3" >0.9987</td>
#                         <td id="T_61350528_f41b_11ea_aa96_309c234564f5row0_col4" class="data row0 col4" >0.9910</td>
#                         <td id="T_61350528_f41b_11ea_aa96_309c234564f5row0_col5" class="data row0 c
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=4605, verbose=0,
#                      warm_start=False)

# %% [markdown]
# ## Create models

# %% [markdown]
# ### Extra Trees Classifier

# %%
et = create_model('et', fold=10)
# Out:
# <style  type="text/css" >
# #T_aec51ca2_f45a_11ea_beea_309c234564f5row10_col0,#T_aec51ca2_f45a_11ea_beea_309c234564f5row10_col1,#T_aec51ca2_f45a_11ea_beea_309c234564f5row10_col2,#T_aec51ca2_f45a_11ea_beea_309c234564f5row10_col3,#T_aec51ca2_f45a_11ea_beea_309c234564f5row10_col4,#T_aec51ca2_f45a_11ea_beea_309c234564f5row10_col5,#T_aec51ca2_f45a_11ea_beea_309c234564f5row10_col6{
#             background:  yellow;
#         }</style><table id="T_aec51ca2_f45a_11ea_beea_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aec51ca2_f45a_11ea_beea_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row0_col0" class="data row0 col0" >0.9954</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row0_col1" class="data row0 col1" >0.9996</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row0_col2" class="data row0 col2" >0.9990</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row0_col3" class="data row0 col3" >0.9920</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row0_col4" class="data row0 col4" >0.9955</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row0_col5" class="data row0 col5" >0.9909</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row0_col6" class="data row0 col6" >0.9909</td>
#             </tr>
#             <tr>
#                         <th id="T_aec51ca2_f45a_11ea_beea_309c234564f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row1_col0" class="data row1 col0" >0.9937</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row1_col1" class="data row1 col1" >0.9996</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row1_col2" class="data row1 col2" >0.9980</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row1_col3" class="data row1 col3" >0.9896</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row1_col4" class="data row1 col4" >0.9938</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row1_col5" class="data row1 col5" >0.9875</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row1_col6" class="data row1 col6" >0.9875</td>
#             </tr>
#             <tr>
#                         <th id="T_aec51ca2_f45a_11ea_beea_309c234564f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row2_col0" class="data row2 col0" >0.9953</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row2_col1" class="data row2 col1" >0.9998</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row2_col2" class="data row2 col2" >0.9992</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row2_col3" class="data row2 col3" >0.9915</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row2_col4" class="data row2 col4" >0.9953</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row2_col5" class="data row2 col5" >0.9906</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row2_col6" class="data row2 col6" >0.9906</td>
#             </tr>
#             <tr>
#                         <th id="T_aec51ca2_f45a_11ea_beea_309c234564f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row3_col0" class="data row3 col0" >0.9942</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row3_col1" class="data row3 col1" >0.9997</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row3_col2" class="data row3 col2" >0.9987</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row3_col3" class="data row3 col3" >0.9897</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row3_col4" class="data row3 col4" >0.9942</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row3_col5" class="data row3 col5" >0.9883</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row3_col6" class="data row3 col6" >0.9884</td>
#             </tr>
#             <tr>
#                         <th id="T_aec51ca2_f45a_11ea_beea_309c234564f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row4_col0" class="data row4 col0" >0.9952</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row4_col1" class="data row4 col1" >0.9998</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row4_col2" class="data row4 col2" >0.9989</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row4_col3" class="data row4 col3" >0.9916</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row4_col4" class="data row4 col4" >0.9953</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row4_col5" class="data row4 col5" >0.9904</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row4_col6" class="data row4 col6" >0.9905</td>
#             </tr>
#             <tr>
#                         <th id="T_aec51ca2_f45a_11ea_beea_309c234564f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row5_col0" class="data row5 col0" >0.9950</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row5_col1" class="data row5 col1" >0.9995</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row5_col2" class="data row5 col2" >0.9987</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row5_col3" class="data row5 col3" >0.9914</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row5_col4" class="data row5 col4" >0.9950</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row5_col5" class="data row5 col5" >0.9900</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row5_col6" class="data row5 col6" >0.9900</td>
#             </tr>
#             <tr>
#                         <th id="T_aec51ca2_f45a_11ea_beea_309c234564f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row6_col0" class="data row6 col0" >0.9942</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row6_col1" class="data row6 col1" >0.9997</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row6_col2" class="data row6 col2" >0.9987</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row6_col3" class="data row6 col3" >0.9899</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row6_col4" class="data row6 col4" >0.9943</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row6_col5" class="data row6 col5" >0.9885</td>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row6_col6" class="data row6 col6" >0.9885</td>
#             </tr>
#             <tr>
#                         <th id="T_aec51ca2_f45a_11ea_beea_309c234564f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_aec51ca2_f45a_11ea_beea_309c234564f5row7_co

# %% [markdown]
# ## Evaluate Models

# %%
plot_model(et)

# %%
#plot_model(et, plot = 'threshold')

# %%
plot_model(et, plot = 'pr')

# %%
plot_model(et, plot='confusion_matrix')

# %%
plot_model(et, plot = 'error')

# %%
plot_model(et, plot = 'class_report')

# %%
plot_model(et, plot = 'boundary')

# %%
#plot_model(et, plot='learning')

# %%
#plot_model(et, plot = 'manifold')

# %%
#plot_model(et, plot = 'calibration')

# %%
#plot_model(et, plot = 'vc')

# %%
#plot_model(et, plot='dimension')

# %%
plot_model(et, plot = 'feature')

# %%
plot_model(et, plot = 'parameter')
# Out:
#                          Parameters
# bootstrap                     False
# ccp_alpha                         0
# class_weight                   None
# criterion                      gini
# max_depth                      None
# max_features                   auto
# max_leaf_nodes                 None
# max_samples                    None
# min_impurity_decrease             0
# min_impurity_split             None
# min_samples_leaf                  1
# min_samples_split                 2
# min_weight_fraction_leaf          0
# n_estimators                    100
# n_jobs                           -1
# oob_score                     False
# random_state                   4605
# verbose                           0
# warm_start                    False

# %% [markdown]
# # Predict models

# %% [markdown]
# # The golden moment... put 10% sample test data through the models...

# %% [markdown]
# # Recombine test_features, test_target at first train/test/split
#  This "test" set was split BEFORE Oversampling. PyCaret takes the "train" from this split and splits it internally again. Since we have no control of how PyCaret does this we needed to do a train/test split before we input the training set into PyCaret. Now we will recombine the test_features and test_target into one new df

# %%
test_features.shape
# Out:
# (24095, 31)

# %%
test_target.shape
# Out:
# (24095,)

# %%
test_df = test_features.copy()

# %%
test_df['zeroBalCode'] = test_target

# %%
test_df.shape
# Out:
# (24095, 32)

# %%
totalTestCount = test_df.zeroBalCode.value_counts().sum()
posTestCount = test_df.zeroBalCode.value_counts()[1]
print('#############################################')
print('This "Test" set has not been oversamplied')
print(test_df.zeroBalCode.value_counts())
print(f'Positive samples are {round(posTestCount/totalTestCount*100,2)}%')
# Out:
# #############################################
# This "Test" set has not been oversamplied
# 0    21971
# 1     2124
# Name: zeroBalCode, dtype: int64
# Positive samples are 8.82%

# %%
#plot_model(qda, plot = 'feature')

# %% [markdown]
# ## Create Confusion Matrix output functions

# %%
def calc_confusion(row):
    if ((row['zeroBalCode'] == 0) & (row['Label'] == 0)):
        value = 'TrueNegative'
    elif ((row['zeroBalCode'] == 0) & (row['Label'] == 1)):
        value = 'FalsePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 1)):
        value = 'TruePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 0)):
        value = 'FalseNegative'
    else:
        value = 'Undefined'
    return value

# %%
def cM(df):
    print(f'           ##############################')
    print(f'           #             #              #')
    print(f'         0 #    {df["TrueNegative"]}     #     {df["FalseNegative"]}      #')
    print(f'  True     #             #              #')
    print(f'  Class    ##############################')
    print(f'           #             #              #')
    print(f'         1 #    {df["FalsePositive"]}      #     {df["TruePositive"]}      #')
    print(f'           #             #              #')
    print(f'           ##############################')
    print(f'                  0              1        ')
    print(f'                  Predicted Class           ')

# %%
def cMCalc():
    # 0 or 2 = Predict equals truth, 1 = Predict doesn't equal truth
    totalNegative = confusionMatrix['TrueNegative'] + confusionMatrix['FalseNegative']
    totalPositive = confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']
    total = totalNegative + totalPositive
    trueNegativePct = confusionMatrix['TrueNegative'] / total * 100
    falseNegativePct = confusionMatrix['FalseNegative'] / total * 100
    truePositivePct = confusionMatrix['TruePositive'] / total * 100
    falsePositivePct = confusionMatrix['FalsePositive'] / total * 100

    # Accuracy Calculation
    accuracy = (confusionMatrix['TruePositive'] + confusionMatrix['TrueNegative'])/(totalPositive + totalNegative)
    # Recall Calculation
    recall = (confusionMatrix['TruePositive']/(confusionMatrix['TruePositive'] + confusionMatrix['FalseNegative']))
    # Precision Calculation
    precision = (confusionMatrix['TruePositive']/(confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']))

    print(f'TrueNegative:  {round(trueNegativePct,2)}%')
    print(f'FalseNegative:  {round(falseNegativePct,2)}%')
    print(f'TruePositive:   {round(truePositivePct,2)}%')
    print(f'FalsePositive: {round(falsePositivePct,2)}%')
    print(f'#####################################################')
    print(f'Accuracy: {round(accuracy,2)*100}%   Recall: {round(recall,2)*100}%   Precision: {round(precision,2)*100}%')
    print(f'#####################################################')

# %% [markdown]
# # Evaluate Models

# %% [markdown]
# # Extra Trees Classifier

# %%
predictions = predict_model(et, data=test_df)

# %%
pd.set_option('max_columns',None)
predictions.head()
# Out:
#   origChannel                                 sellerName  origIntRate  \
# 0           R                     WELLS FARGO BANK, N.A.        4.750
# 1           C                      BANK OF AMERICA, N.A.        4.875
# 2           R  JPMORGAN CHASE BANK, NATIONAL ASSOCIATION        4.875
# 3           R                   PHH MORTGAGE CORPORATION        3.750
# 4           R                                      OTHER        4.000
#
#    origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio  \
# 0   248000           360       90      90.0             1                44
# 1   289000           360       89      89.0             2                40
# 2   230000           360       80      80.0             2                41
# 3   140000           180       80      80.0             1                22
# 4   220000           360       80      80.0             2                39
#
#   loanPurp propState  zipCode  pMIperct  mortInsType  bestCreditScore  \
# 0        R        MD      210      25.0            1              703
# 1        R        RI       28      25.0            1              776
# 2        C        NJ       77       0.0            0              784
# 3        C        TN      373       0.0            0              670
# 4        C        MI      491       0.0            0              746
#
#    worstCreditScore  avgCreditScore  loanAge    mSA  fmacRateMax  fmacRateMin  \
# 0               703             703       72  12580         4.91         4.82
# 1               776             776       70  39300         4.91         4.82
# 2               784             784       68  35620         4.91         4.82
# 3               670             670       71      0         3.71         3.66
# 4               745             745       83  35660         3.66         3.55
#
#    fmacRateAvg  fmacRateVolatility  rateDiffAbove  rateDiffBelow  rateDiffAvg  \
# 0       4.8575            0.018672         -0.160          0.070      -0.1075
# 1       4.8575            0.018672         -0.035         -0.055       0.0175
# 2       4.8575            0.018672         -0.035         -0.055       0.0175
# 3       3.6750            0.013661          0.040         -0.090       0.0750
# 4       3.6020            0.030986          0.340         -0.450       0.3980
#
#    rateDiffAbovePct  rateDiffBelowPct  rateDiffAvgPct  origYear  origMonth  \
# 0         -0.032587          0.014523       -0.022131      2009          5
# 1         -0.007128         -0.011411        0.003603      2009          5
# 2         -0.007128         -0.011411        0.003603      2009          5
# 3          0.010782         -0.024590        0.020408      2012          6
# 4          0.092896         -0.126761        0.110494      2012          8
#
#    zeroBalCode  Label  Score
# 0            0      0   0.38
# 1            0      0   0.41
# 2            0      0   0.05
# 3            0      0   0.06
# 4            1      0   0.05

# %%
results = predictions[['zeroBalCode','Label','Score']]

# %%
predictions.Label.value_counts()
# Out:
# 0    24043
# 1       52
# Name: Label, dtype: int64

# %%
results['Confusion'] = results.apply(calc_confusion, axis=1)

# %%
confusionMatrix = results.Confusion.value_counts().to_dict()

# %%
cM(confusionMatrix)
# Out:
#            ##############################
#            #             #              #
#          0 #    21938     #     2105      #
#   True     #             #              #
#   Class    ##############################
#            #             #              #
#          1 #    33      #     19      #
#            #             #              #
#            ##############################
#                   0              1
#                   Predicted Class

# %%
cMCalc()
# Out:
# TrueNegative:  91.05%
# FalseNegative:  8.74%
# TruePositive:   0.08%
# FalsePositive: 0.14%
# #####################################################
# Accuracy: 91.0%   Recall: 1.0%   Precision: 37.0%
# #####################################################

# %% [markdown]
# #### Well this is disappointing... The non-oversampled test dataset performed worse than random flipping a coin!

# %%
#save_model(et, 'extraTrees2.5OS5050_082220')

# %%
#save_model(calibrated_et, 'extraTreesCalibrated2.5OS5050_082220')

# %%
pred_holdout = predict_model(et)
# Out:
#                     Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# 0  Extra Trees Classifier    0.9961  0.9998  0.9993  0.9931  0.9962  0.9923
#
#       MCC
# 0  0.9923
