# %% [markdown]
# # ML Foreclosure Binary Classification - EPOCH1 25% sample dataset
# Only "resolved" outcomes - Either paid off or default
#
#     target = zeroBalCode (set to object dtype)
#     Binary classification sets zeroBalCode to either "0" or "1" for the 7 possible outcomes
#
#     "0" = "Loan Success"
#         * 01 = Prepaid or Matured
#         * 06 = Repurchased
#         * 16 = Reperforming Loan Sale
#
#     "1" =  "Loan Failure" - Most likely loss of money (but not necessarily) one of below conditions:
#         * 02 = Third Party Sale
#         * 03 = Short Sale
#         * 09 = Deed-in-Lieu,REO
#         * 15 = Note Sale

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#!pip install pycaret
from imblearn.over_sampling import RandomOverSampler
from pycaret.classification import *
#from pycaret.regression import *
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importing the data - don't use *.ML.csv files!!!
# If you have *.MLReady.csv then [click here](#MLReady)

# %%
df=pd.read_csv("data/FM_Acq2_Perf_FMAC_EPOCH1_loanAge_25pct.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            id origChannel              sellerName  \
# 0     1048254       1049049  143230100085           C      CITIMORTGAGE, INC.
# 1     1503985       1504780  744606264337           B  WELLS FARGO BANK, N.A.
# 2      366713        367508  497170964573           R    RBC MORTGAGE COMPANY
# 3     1344840       1345635  845160346803           R      CITIMORTGAGE, INC.
# 4     1034016       1034811  794196321261           R                   OTHER
#
#    origIntRate  origUPB  origLoanTerm    origDate  origLTV  origCLTV  \
# 0        5.625   166000           360  2003-04-01     80.0      80.0
# 1        4.500   123000           120  2004-04-01     27.0      27.0
# 2        6.500   177000           360  2001-11-01     78.0      78.0
# 3        5.750   191000           180  2003-09-01     26.0      26.0
# 4        6.125    95000           360  2003-04-01     80.0      80.0
#
#    numBorrowers  origDebtIncRatio loanPurp propState  zipCode  pMIperct  \
# 0           2.0              26.0        R        AL      350       0.0
# 1           2.0              56.0        R        NJ       80       0.0
# 2           2.0              30.0        R        WA      986       0.0
# 3           2.0               9.0        R        WA      980       0.0
# 4           2.0              47.0        R        IL      626       0.0
#
#    mortInsType  bestCreditScore  worstCreditScore  avgCreditScore  loanAge  \
# 0          0.0            740.0             740.0           740.0      185
# 1          0.0            784.0             705.0           744.5      119
# 2          0.0            586.0             586.0           586.0       42
# 3          0.0            771.0             760.0           765.5       63
# 4          0.0            746.0             743.0           744.5      140
#
#    monMatur    mSA  zeroBalCode  deliqGood  deliqBad  deliqMax  fmacRateMax  \
# 0     380.0  13820          9.0        166        17      10.0         5.85
# 1       1.0  37980          1.0        118         1       1.0         6.01
# 2     318.0  38900          1.0         27        15       2.0         7.02
# 3     117.0  42660          1.0         61         1       1.0         6.44
# 4     220.0      0          1.0        139         2       2.0         5.85
#
#    fmacRateMin  fmacRateAvg  fmacRateVolatility  fredRate  rateDiffAbove  \
# 0         5.79       5.8125            0.010363      3.84         -0.225
# 1         5.52       5.8300            0.088768      3.91         -1.510
# 2         6.45       6.6580            0.088372      4.24         -0.520
# 3         5.98       6.1475            0.076923      4.45         -0.690
# 4         5.79       5.8125            0.010363      3.84          0.275
#
#    rateDiffBelow  rateDiffAvg  rateDiffAbovePct  rateDiffBelowPct  \
# 0          0.165      -0.1875         -0.038462          0.028497
# 1          1.020      -1.3300         -0.251248          0.184783
# 2         -0.050      -0.1580         -0.074074         -0.007752
# 3          0.230      -0.3975         -0.107143          0.038462
# 4         -0.335       0.3125          0.047009         -0.057858
#
#    rateDiffAvgPct
# 0       -0.032258
# 1       -0.228130
# 2       -0.023731
# 3       -0.064660
# 4        0.053763

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569592 entries, 0 to 569591
# Data columns (total 39 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          569592 non-null  int64
#  1   Unnamed: 0.1        569592 non-null  int64
#  2   id                  569592 non-null  int64
#  3   origChannel         569592 non-null  object
#  4   sellerName          569592 non-null  object
#  5   origIntRate         569592 non-null  float64
#  6   origUPB             569592 non-null  int64
#  7   origLoanTerm        569592 non-null  int64
#  8   origDate            569592 non-null  object
#  9   origLTV             569592 non-null  float64
#  10  origCLTV            569592 non-null  float64
#  11  numBorrowers        569592 non-null  float64
#  12  origDebtIncRatio    569592 non-null  float64
#  13  loanPurp            569592 non-null  object
#  14  propState           569592 non-null  object
#  15  zipCode             569592 non-null  int64
#  16  pMIperct            569592 non-null  float64
#  17  mortInsType         569592 non-null  float64
#  18  bestCreditScore     569592 non-null  float64
#  19  worstCreditScore    569592 non-null  float64
#  20  avgCreditScore      569592 non-null  float64
#  21  loanAge             569592 non-null  int64
#  22  monMatur            569198 non-null  float64
#  23  mSA                 569592 non-null  int64
#  24  zeroBalCode         569592 non-null  float64
#  25  deliqGood           569592 non-null  int64
#  26  deliqBad            569592 non-null  int64
#  27  deliqMax            569592 non-null  float64
#  28  fmacRateMax         569592 non-null  float64
#  29  fmacRateMin         569592 non-null  float64
#  30  fmacRateAvg         569592 non-null  float64
#  31  fmacRateVolatility  569592 non-null  float64
#  32  fredRate            569592 non-null  float64
#  33  rateDiffAbove       569592 non-null  float64
#  34  rateDiffBelow       569592 non-null  float64
#  35  rateDiffAvg         569592 non-null  float64
#  36  rateDiffAbovePct    569592 non-null  float64
#  37  rateDiffBelowPct    569592 non-null  float64
#  38  rateDiffAvgPct      569592 non-null  float64
# dtypes: float64(24), int64(10), object(5)
# memory usage: 169.5+ MB

# %% [markdown]
# ## Remove columns not involved in 'Foreclosure or Not' query

# %%
df.drop(['Unnamed: 0','id','fredRate',\
         'bestCreditScore','worstCreditScore','monMatur',\
         'deliqGood','deliqBad','deliqMax',\
        'fmacRateMax','fmacRateMin','fmacRateVolatility',\
        'rateDiffAbove','rateDiffBelow','rateDiffAbovePct','rateDiffBelowPct',\
        ],1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569592 entries, 0 to 569591
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0.1      569592 non-null  int64
#  1   origChannel       569592 non-null  object
#  2   sellerName        569592 non-null  object
#  3   origIntRate       569592 non-null  float64
#  4   origUPB           569592 non-null  int64
#  5   origLoanTerm      569592 non-null  int64
#  6   origDate          569592 non-null  object
#  7   origLTV           569592 non-null  float64
#  8   origCLTV          569592 non-null  float64
#  9   numBorrowers      569592 non-null  float64
#  10  origDebtIncRatio  569592 non-null  float64
#  11  loanPurp          569592 non-null  object
#  12  propState         569592 non-null  object
#  13  zipCode           569592 non-null  int64
#  14  pMIperct          569592 non-null  float64
#  15  mortInsType       569592 non-null  float64
#  16  avgCreditScore    569592 non-null  float64
#  17  loanAge           569592 non-null  int64
#  18  mSA               569592 non-null  int64
#  19  zeroBalCode       569592 non-null  float64
#  20  fmacRateAvg       569592 non-null  float64
#  21  rateDiffAvg       569592 non-null  float64
#  22  rateDiffAvgPct    569592 non-null  float64
# dtypes: float64(12), int64(6), object(5)
# memory usage: 99.9+ MB

# %% [markdown]
# ### Check if any columns have a null value

# %%
df.apply(lambda x: x.isnull().sum(), axis=0)
# Out:
# Unnamed: 0.1        0
# origChannel         0
# sellerName          0
# origIntRate         0
# origUPB             0
# origLoanTerm        0
# origDate            0
# origLTV             0
# origCLTV            0
# numBorrowers        0
# origDebtIncRatio    0
# loanPurp            0
# propState           0
# zipCode             0
# pMIperct            0
# mortInsType         0
# avgCreditScore      0
# loanAge             0
# mSA                 0
# zeroBalCode         0
# fmacRateAvg         0
# rateDiffAvg         0
# rateDiffAvgPct      0
# dtype: int64

# %% [markdown]
# ## Engineer originDate into Date features

# %%
df['origDate'] = pd.to_datetime(df['origDate'])

# %%
df['origYear'] = df['origDate'].dt.year
df['origMonth'] = df['origDate'].dt.month

# %%
df.drop(['origDate'],1,inplace=True)

# %%
df[['origYear','origMonth']].head()
# Out:
#    origYear  origMonth
# 0      2003          4
# 1      2004          4
# 2      2001         11
# 3      2003          9
# 4      2003          4

# %% [markdown]
# # Turn zero Balance Code Into binary "0" GOOD and "1" BAD

# %%
df.zeroBalCode.unique()
# Out:
# array([ 9.,  1., 16.,  3.,  6., 15.,  2.])

# %%
df['zeroBalCode'] = df.zeroBalCode.replace([1,6,16],0)
df['zeroBalCode'] = df.zeroBalCode.replace([9,3,2,15],1)

# %%
df.zeroBalCode.unique()
# Out:
# array([1., 0.])

# %%
#Checking datatypes of individual feature
df.head()
# Out:
#    Unnamed: 0.1 origChannel              sellerName  origIntRate  origUPB  \
# 0       1049049           C      CITIMORTGAGE, INC.        5.625   166000
# 1       1504780           B  WELLS FARGO BANK, N.A.        4.500   123000
# 2        367508           R    RBC MORTGAGE COMPANY        6.500   177000
# 3       1345635           R      CITIMORTGAGE, INC.        5.750   191000
# 4       1034811           R                   OTHER        6.125    95000
#
#    origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio loanPurp  \
# 0           360     80.0      80.0           2.0              26.0        R
# 1           120     27.0      27.0           2.0              56.0        R
# 2           360     78.0      78.0           2.0              30.0        R
# 3           180     26.0      26.0           2.0               9.0        R
# 4           360     80.0      80.0           2.0              47.0        R
#
#   propState  zipCode  pMIperct  mortInsType  avgCreditScore  loanAge    mSA  \
# 0        AL      350       0.0          0.0           740.0      185  13820
# 1        NJ       80       0.0          0.0           744.5      119  37980
# 2        WA      986       0.0          0.0           586.0       42  38900
# 3        WA      980       0.0          0.0           765.5       63  42660
# 4        IL      626       0.0          0.0           744.5      140      0
#
#    zeroBalCode  fmacRateAvg  rateDiffAvg  rateDiffAvgPct  origYear  origMonth
# 0          1.0       5.8125      -0.1875       -0.032258      2003          4
# 1          0.0       5.8300      -1.3300       -0.228130      2004          4
# 2          0.0       6.6580      -0.1580       -0.023731      2001         11
# 3          0.0       6.1475      -0.3975       -0.064660      2003          9
# 4          0.0       5.8125       0.3125        0.053763      2003          4

# %% [markdown]
# # Review values for dates and slice (if needed) the timeframe you want

# %%
df.origYear.unique()
# Out:
# array([2003, 2004, 2001, 2000, 2002, 2006, 2005, 2007, 2008, 1999],
#       dtype=int64)

# %%
df['origMonth'].unique()
# Out:
# array([ 4, 11,  9,  7,  3,  5,  6, 10,  1,  8,  2, 12], dtype=int64)

# %%
df.head()
# Out:
#    Unnamed: 0.1 origChannel              sellerName  origIntRate  origUPB  \
# 0       1049049           C      CITIMORTGAGE, INC.        5.625   166000
# 1       1504780           B  WELLS FARGO BANK, N.A.        4.500   123000
# 2        367508           R    RBC MORTGAGE COMPANY        6.500   177000
# 3       1345635           R      CITIMORTGAGE, INC.        5.750   191000
# 4       1034811           R                   OTHER        6.125    95000
#
#    origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio loanPurp  \
# 0           360     80.0      80.0           2.0              26.0        R
# 1           120     27.0      27.0           2.0              56.0        R
# 2           360     78.0      78.0           2.0              30.0        R
# 3           180     26.0      26.0           2.0               9.0        R
# 4           360     80.0      80.0           2.0              47.0        R
#
#   propState  zipCode  pMIperct  mortInsType  avgCreditScore  loanAge    mSA  \
# 0        AL      350       0.0          0.0           740.0      185  13820
# 1        NJ       80       0.0          0.0           744.5      119  37980
# 2        WA      986       0.0          0.0           586.0       42  38900
# 3        WA      980       0.0          0.0           765.5       63  42660
# 4        IL      626       0.0          0.0           744.5      140      0
#
#    zeroBalCode  fmacRateAvg  rateDiffAvg  rateDiffAvgPct  origYear  origMonth
# 0          1.0       5.8125      -0.1875       -0.032258      2003          4
# 1          0.0       5.8300      -1.3300       -0.228130      2004          4
# 2          0.0       6.6580      -0.1580       -0.023731      2001         11
# 3          0.0       6.1475      -0.3975       -0.064660      2003          9
# 4          0.0       5.8125       0.3125        0.053763      2003          4

# %% [markdown]
# # Coerce the column dtype (int in this case)

# %%
df = df.astype({'origLTV':'int','origCLTV':'int','numBorrowers':'int','origDebtIncRatio':'int',\
               'mortInsType':'int','loanAge':'int',\
               'avgCreditScore':'int','zeroBalCode':'int'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569592 entries, 0 to 569591
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0.1      569592 non-null  int64
#  1   origChannel       569592 non-null  object
#  2   sellerName        569592 non-null  object
#  3   origIntRate       569592 non-null  float64
#  4   origUPB           569592 non-null  int64
#  5   origLoanTerm      569592 non-null  int64
#  6   origLTV           569592 non-null  int32
#  7   origCLTV          569592 non-null  int32
#  8   numBorrowers      569592 non-null  int32
#  9   origDebtIncRatio  569592 non-null  int32
#  10  loanPurp          569592 non-null  object
#  11  propState         569592 non-null  object
#  12  zipCode           569592 non-null  int64
#  13  pMIperct          569592 non-null  float64
#  14  mortInsType       569592 non-null  int32
#  15  avgCreditScore    569592 non-null  int32
#  16  loanAge           569592 non-null  int32
#  17  mSA               569592 non-null  int64
#  18  zeroBalCode       569592 non-null  int32
#  19  fmacRateAvg       569592 non-null  float64
#  20  rateDiffAvg       569592 non-null  float64
#  21  rateDiffAvgPct    569592 non-null  float64
#  22  origYear          569592 non-null  int64
#  23  origMonth         569592 non-null  int64
# dtypes: float64(5), int32(8), int64(7), object(4)
# memory usage: 86.9+ MB

# %% [markdown]
# <a id='MLReady'></a>

# %% [markdown]
# # Train Test Split to create holdout dataset outside of PyCaret

# %%
good = df.zeroBalCode.value_counts()[0]
bad = df.zeroBalCode.value_counts()[1]
perct_bad = round(bad/(good + bad)*100,2)
print(f'We have {perct_bad}% Foreclosures in our dataset')
# Out:
# We have 15.45% Foreclosures in our dataset

# %%
from sklearn.model_selection import train_test_split

training_features, test_features, \
training_target, test_target, = train_test_split(
    df.drop(['zeroBalCode'], axis=1)
    , df['zeroBalCode']
    , test_size = .1
    , random_state=12
)

# %%
# Further split the training data into training/test
x_train, x_val, y_train, y_val = train_test_split(
    training_features
    , training_target
    , test_size = .1
    ,random_state=12
)

# %%
# For the training data, randomly sample 
# ros = RandomOverSampler(sampling_strategy='minority')
# x_train_res, y_train_res = ros.fit_sample(x_train, y_train)

# %%
print('#############################################')
print('Before oversampling: "Closed" crushes "Default" and causes issues:')
print(training_target.value_counts())
# print('')
# print('Before oversampling: "Closed" and "Default" are equal')
# print(y_train_res.value_counts())
# Out:
# #############################################
# Before oversampling: "Closed" crushes "Default" and causes issues:
# 0    433522
# 1     79110
# Name: zeroBalCode, dtype: int64

# %% [markdown]
# # Recombine X_train_res, y_train_res so PyCaret can deal with one df

# %%
y_train.shape
# Out:
# (461368,)

# %%
df = x_train.copy()

# %%
df['zeroBalCode'] = y_train

# %%
df.shape
# Out:
# (461368, 24)

# %% [markdown]
# # Review metrics last time before run (to have record of starting values)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 461368 entries, 426394 to 516955
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0.1      461368 non-null  int64
#  1   origChannel       461368 non-null  object
#  2   sellerName        461368 non-null  object
#  3   origIntRate       461368 non-null  float64
#  4   origUPB           461368 non-null  int64
#  5   origLoanTerm      461368 non-null  int64
#  6   origLTV           461368 non-null  int32
#  7   origCLTV          461368 non-null  int32
#  8   numBorrowers      461368 non-null  int32
#  9   origDebtIncRatio  461368 non-null  int32
#  10  loanPurp          461368 non-null  object
#  11  propState         461368 non-null  object
#  12  zipCode           461368 non-null  int64
#  13  pMIperct          461368 non-null  float64
#  14  mortInsType       461368 non-null  int32
#  15  avgCreditScore    461368 non-null  int32
#  16  loanAge           461368 non-null  int32
#  17  mSA               461368 non-null  int64
#  18  fmacRateAvg       461368 non-null  float64
#  19  rateDiffAvg       461368 non-null  float64
#  20  rateDiffAvgPct    461368 non-null  float64
#  21  origYear          461368 non-null  int64
#  22  origMonth         461368 non-null  int64
#  23  zeroBalCode       461368 non-null  int32
# dtypes: float64(5), int32(8), int64(7), object(4)
# memory usage: 73.9+ MB

# %%
df.head()
# Out:
#         Unnamed: 0.1 origChannel               sellerName  origIntRate  \
# 426394        745223           C       FLAGSTAR BANK, FSB        5.375
# 839           237214           C  JPMORGAN CHASE BANK, NA        8.250
# 472984        175628           B    BANK OF AMERICA, N.A.        7.500
# 48956         518150           C    BANK OF AMERICA, N.A.        6.750
# 537190        605236           B       FLAGSTAR BANK, FSB        6.375
#
#         origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  \
# 426394   178000           180       66        66             1
# 839       55000           360       60        60             1
# 472984    83000           360       75        75             1
# 48956    116000           120       67        67             2
# 537190   153000           360       72        72             1
#
#         origDebtIncRatio loanPurp propState  zipCode  pMIperct  mortInsType  \
# 426394                37        C        IN      462       0.0            0
# 839                   33        C        NC      277       0.0            0
# 472984                58        R        KY      405       0.0            0
# 48956                 35        R        FL      320       0.0            0
# 537190                44        P        MI      481       0.0            0
#
#         avgCreditScore  loanAge    mSA  fmacRateAvg  rateDiffAvg  \
# 426394             775       40  26900       6.0680      -0.6930
# 839                565       22  20500       7.0775       1.1725
# 472984             664       50  30460       7.0500       0.4500
# 48956              792       17  27260       6.8925      -0.1425
# 537190             734       72  19820       6.2900       0.0850
#
#         rateDiffAvgPct  origYear  origMonth  zeroBalCode
# 426394       -0.114206      2002         11            0
# 839           0.165666      2001          4            0
# 472984        0.063830      2001          2            1
# 48956        -0.020675      2002          2            0
# 537190        0.013514      2002          8            1

# %% [markdown]
# # Pycaret - Setup with categorical definition

# %% [markdown]
# ### Use complex setup

# %%
model_setup = setup(
    df
    , target = 'zeroBalCode' # PyCaret will list this as "Label"
    , normalize = True
    , transformation = False
    , pca = False 
    , ignore_low_variance = False # Variance is calculated using the ratio of unique values to the number of samples, and the ratio of the most common value to the frequency of the second most common value. 
    , ignore_features = None
    , handle_unknown_categorical = True
    , remove_outliers = True
    , remove_multicollinearity = False
    , polynomial_features = False
    , trigonometry_features = False
    , feature_selection = False
    , feature_interaction = False
    , fix_imbalance = False
    , silent = True
    , profile = False
    # outliers from the training data are removed using PCA linear dimensionality reduction using the Singular Value Decomposition technique.
    , bin_numeric_features = [
        'avgCreditScore'
        ] # Set to True to bin numerics using K Means
    , categorical_features = [
         'origChannel'
        , 'loanPurp'
        , 'origYear'
        , 'origMonth'
        , 'mortInsType'
        , 'origLoanTerm'
        ]
    , high_cardinality_features = [
         'propState'
        , 'sellerName'
        , 'mSA'
        , 'zipCode'
    ]
    , high_cardinality_method = 'clustering'
    , numeric_features = [
        'origIntRate'
        , 'numBorrowers'
        , 'origUPB'
        , 'origLTV'
        , 'origCLTV'
        , 'pMIperct'
        , 'loanAge'
        , 'origDebtIncRatio'
        , 'avgCreditScore'
        , 'rateDiffAvg'
        , 'rateDiffAvgPct'
        , 'fmacRateAvg'
    ]
)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# #T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row8_col1,#T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row15_col1,#T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row25_col1,#T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row26_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row0_col1" class="data row0 col1" >5814</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row3_col1" class="data row3 col1" >(461368, 24)</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row5_col1" class="data row5 col1" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row6_col1" class="data row6 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row8_col1" class="data row8 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row9_col1" class="data row9 col1" >clustering</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row10_col1" class="data row10 col1" >(438299, 24)</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row11_col1" class="data row11 col1" >(306809, 68)</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row12_col1" class="data row12 col1" >(131490, 68)</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row15_col1" class="data row15 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row16_col1" class="data row16 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c6d0f8c0_fc39_11ea_9b99_309c234564f5level0_row18" class="row_heading level0 row18" >18</th>

# %% [markdown]
# ## Compare Models with no blacklist exclusions

# %%
model_results=compare_models(sort='Recall') #blacklist = ['tr','ransac'],'lar','par','huber','llar','lasso','en','ridge','omp','br','svm'])
model_results
# Out:
# <style  type="text/css" >
#     #T_bbb91036_fc3f_11ea_97f7_309c234564f5 th {
#           text-align: left;
#     }#T_bbb91036_fc3f_11ea_97f7_309c234564f5row0_col0,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row0_col1,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row0_col2,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row0_col4,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row0_col6,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row0_col7,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row1_col0,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row1_col1,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row1_col2,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row1_col3,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row1_col4,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row1_col5,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row1_col6,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row1_col7,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row2_col0,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row2_col1,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row2_col2,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row2_col3,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row2_col4,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row2_col5,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row2_col6,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row2_col7,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row3_col0,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row3_col3,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row3_col4,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row3_col5,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row4_col0,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row4_col1,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row4_col2,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row4_col3,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row4_col4,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row4_col5,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row4_col6,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row4_col7,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row5_col0,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row5_col1,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row5_col2,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row5_col3,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row5_col4,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row5_col5,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row5_col6,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row5_col7,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row6_col0,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row6_col1,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row6_col2,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row6_col3,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row6_col5,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row6_col6,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row6_col7,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row7_col0,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row7_col1,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row7_col2,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row7_col3,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row7_col4,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row7_col5,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row7_col6,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row7_col7,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row8_col0,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row8_col1,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row8_col2,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row8_col3,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row8_col4,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row8_col5,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row8_col6,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row8_col7,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row9_col0,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row9_col1,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row9_col2,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row9_col3,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row9_col4,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row9_col5,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row9_col6,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row9_col7,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row10_col0,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row10_col1,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row10_col2,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row10_col3,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row10_col4,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row10_col5,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row10_col6,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row10_col7,#T_bbb91036_fc3f_1 ...
#             text-align:  left;
#         }#T_bbb91036_fc3f_11ea_97f7_309c234564f5row0_col3,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row0_col5,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row3_col1,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row3_col2,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row3_col6,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row3_col7,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row6_col4{
#             background-color:  yellow;
#             text-align:  left;
#         }#T_bbb91036_fc3f_11ea_97f7_309c234564f5row0_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row1_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row2_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row3_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row4_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row5_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row6_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row7_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row8_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row9_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row10_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row11_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row12_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row13_col8,#T_bbb91036_fc3f_11ea_97f7_309c234564f5row14_col8{
#             background-color:  lightgrey;
#             text-align:  left;
#         }</style><table id="T_bbb91036_fc3f_11ea_97f7_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bbb91036_fc3f_11ea_97f7_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bbb91036_fc3f_11ea_97f7_309c234564f5row0_col0" class="data row0 col0" >Naive Bayes</td>
#                         <td id="T_bbb91036_fc3f_11ea_97f7_309c234564f5row0_col1" class="data row0 col1" >0.7021</td>
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ## Create models

# %% [markdown]
# ### NB Classifier

# %%
nb = create_model('nb', fold=10)
# Out:
# <style  type="text/css" >
# #T_507646e4_fc40_11ea_ab05_309c234564f5row10_col0,#T_507646e4_fc40_11ea_ab05_309c234564f5row10_col1,#T_507646e4_fc40_11ea_ab05_309c234564f5row10_col2,#T_507646e4_fc40_11ea_ab05_309c234564f5row10_col3,#T_507646e4_fc40_11ea_ab05_309c234564f5row10_col4,#T_507646e4_fc40_11ea_ab05_309c234564f5row10_col5,#T_507646e4_fc40_11ea_ab05_309c234564f5row10_col6{
#             background:  yellow;
#         }</style><table id="T_507646e4_fc40_11ea_ab05_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_507646e4_fc40_11ea_ab05_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row0_col0" class="data row0 col0" >0.7019</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row0_col1" class="data row0 col1" >0.7527</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row0_col2" class="data row0 col2" >0.6758</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row0_col3" class="data row0 col3" >0.2940</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row0_col4" class="data row0 col4" >0.4097</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row0_col5" class="data row0 col5" >0.2496</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row0_col6" class="data row0 col6" >0.2883</td>
#             </tr>
#             <tr>
#                         <th id="T_507646e4_fc40_11ea_ab05_309c234564f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row1_col0" class="data row1 col0" >0.7024</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row1_col1" class="data row1 col1" >0.7551</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row1_col2" class="data row1 col2" >0.6811</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row1_col3" class="data row1 col3" >0.2953</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row1_col4" class="data row1 col4" >0.4120</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row1_col5" class="data row1 col5" >0.2523</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row1_col6" class="data row1 col6" >0.2918</td>
#             </tr>
#             <tr>
#                         <th id="T_507646e4_fc40_11ea_ab05_309c234564f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row2_col0" class="data row2 col0" >0.6996</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row2_col1" class="data row2 col1" >0.7513</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row2_col2" class="data row2 col2" >0.6847</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row2_col3" class="data row2 col3" >0.2936</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row2_col4" class="data row2 col4" >0.4110</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row2_col5" class="data row2 col5" >0.2504</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row2_col6" class="data row2 col6" >0.2908</td>
#             </tr>
#             <tr>
#                         <th id="T_507646e4_fc40_11ea_ab05_309c234564f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row3_col0" class="data row3 col0" >0.7061</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row3_col1" class="data row3 col1" >0.7588</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row3_col2" class="data row3 col2" >0.6953</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row3_col3" class="data row3 col3" >0.3010</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row3_col4" class="data row3 col4" >0.4201</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row3_col5" class="data row3 col5" >0.2625</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row3_col6" class="data row3 col6" >0.3038</td>
#             </tr>
#             <tr>
#                         <th id="T_507646e4_fc40_11ea_ab05_309c234564f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row4_col0" class="data row4 col0" >0.7056</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row4_col1" class="data row4 col1" >0.7529</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row4_col2" class="data row4 col2" >0.6910</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row4_col3" class="data row4 col3" >0.2997</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row4_col4" class="data row4 col4" >0.4181</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row4_col5" class="data row4 col5" >0.2601</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row4_col6" class="data row4 col6" >0.3008</td>
#             </tr>
#             <tr>
#                         <th id="T_507646e4_fc40_11ea_ab05_309c234564f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row5_col0" class="data row5 col0" >0.7044</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row5_col1" class="data row5 col1" >0.7548</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row5_col2" class="data row5 col2" >0.6746</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row5_col3" class="data row5 col3" >0.2958</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row5_col4" class="data row5 col4" >0.4113</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row5_col5" class="data row5 col5" >0.2522</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row5_col6" class="data row5 col6" >0.2904</td>
#             </tr>
#             <tr>
#                         <th id="T_507646e4_fc40_11ea_ab05_309c234564f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row6_col0" class="data row6 col0" >0.6993</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row6_col1" class="data row6 col1" >0.7491</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row6_col2" class="data row6 col2" >0.6765</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row6_col3" class="data row6 col3" >0.2919</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row6_col4" class="data row6 col4" >0.4079</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row6_col5" class="data row6 col5" >0.2468</td>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row6_col6" class="data row6 col6" >0.2860</td>
#             </tr>
#             <tr>
#                         <th id="T_507646e4_fc40_11ea_ab05_309c234564f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_507646e4_fc40_11ea_ab05_309c234564f5row7_co

# %% [markdown]
# ## Evaluate Models

# %%
evaluate_model(nb)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ## Tune Model

# %%
tuned_nb = tune_model(nb, optimize = 'Recall')
# Out:
# <style  type="text/css" >
# #T_652d211c_fc40_11ea_bcaa_309c234564f5row10_col0,#T_652d211c_fc40_11ea_bcaa_309c234564f5row10_col1,#T_652d211c_fc40_11ea_bcaa_309c234564f5row10_col2,#T_652d211c_fc40_11ea_bcaa_309c234564f5row10_col3,#T_652d211c_fc40_11ea_bcaa_309c234564f5row10_col4,#T_652d211c_fc40_11ea_bcaa_309c234564f5row10_col5,#T_652d211c_fc40_11ea_bcaa_309c234564f5row10_col6{
#             background:  yellow;
#         }</style><table id="T_652d211c_fc40_11ea_bcaa_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_652d211c_fc40_11ea_bcaa_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row0_col0" class="data row0 col0" >0.7019</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row0_col1" class="data row0 col1" >0.7527</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row0_col2" class="data row0 col2" >0.6758</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row0_col3" class="data row0 col3" >0.2940</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row0_col4" class="data row0 col4" >0.4097</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row0_col5" class="data row0 col5" >0.2496</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row0_col6" class="data row0 col6" >0.2883</td>
#             </tr>
#             <tr>
#                         <th id="T_652d211c_fc40_11ea_bcaa_309c234564f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row1_col0" class="data row1 col0" >0.7024</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row1_col1" class="data row1 col1" >0.7551</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row1_col2" class="data row1 col2" >0.6811</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row1_col3" class="data row1 col3" >0.2953</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row1_col4" class="data row1 col4" >0.4120</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row1_col5" class="data row1 col5" >0.2523</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row1_col6" class="data row1 col6" >0.2918</td>
#             </tr>
#             <tr>
#                         <th id="T_652d211c_fc40_11ea_bcaa_309c234564f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row2_col0" class="data row2 col0" >0.6996</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row2_col1" class="data row2 col1" >0.7513</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row2_col2" class="data row2 col2" >0.6847</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row2_col3" class="data row2 col3" >0.2936</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row2_col4" class="data row2 col4" >0.4110</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row2_col5" class="data row2 col5" >0.2504</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row2_col6" class="data row2 col6" >0.2908</td>
#             </tr>
#             <tr>
#                         <th id="T_652d211c_fc40_11ea_bcaa_309c234564f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row3_col0" class="data row3 col0" >0.7061</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row3_col1" class="data row3 col1" >0.7588</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row3_col2" class="data row3 col2" >0.6953</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row3_col3" class="data row3 col3" >0.3010</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row3_col4" class="data row3 col4" >0.4201</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row3_col5" class="data row3 col5" >0.2625</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row3_col6" class="data row3 col6" >0.3038</td>
#             </tr>
#             <tr>
#                         <th id="T_652d211c_fc40_11ea_bcaa_309c234564f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row4_col0" class="data row4 col0" >0.7056</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row4_col1" class="data row4 col1" >0.7529</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row4_col2" class="data row4 col2" >0.6910</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row4_col3" class="data row4 col3" >0.2997</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row4_col4" class="data row4 col4" >0.4181</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row4_col5" class="data row4 col5" >0.2601</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row4_col6" class="data row4 col6" >0.3008</td>
#             </tr>
#             <tr>
#                         <th id="T_652d211c_fc40_11ea_bcaa_309c234564f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row5_col0" class="data row5 col0" >0.7044</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row5_col1" class="data row5 col1" >0.7548</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row5_col2" class="data row5 col2" >0.6746</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row5_col3" class="data row5 col3" >0.2958</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row5_col4" class="data row5 col4" >0.4113</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row5_col5" class="data row5 col5" >0.2522</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row5_col6" class="data row5 col6" >0.2904</td>
#             </tr>
#             <tr>
#                         <th id="T_652d211c_fc40_11ea_bcaa_309c234564f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row6_col0" class="data row6 col0" >0.6993</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row6_col1" class="data row6 col1" >0.7491</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row6_col2" class="data row6 col2" >0.6765</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row6_col3" class="data row6 col3" >0.2919</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row6_col4" class="data row6 col4" >0.4079</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row6_col5" class="data row6 col5" >0.2468</td>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row6_col6" class="data row6 col6" >0.2860</td>
#             </tr>
#             <tr>
#                         <th id="T_652d211c_fc40_11ea_bcaa_309c234564f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_652d211c_fc40_11ea_bcaa_309c234564f5row7_co

# %%
evaluate_model(tuned_nb)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
final_nb = finalize_model(tuned_nb)

# %%
evaluate_model(final_nb)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# # Predict models

# %%
predicted_final_nb = predict_model(final_nb)
# Out:
#          Model  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Naive Bayes    0.7049  0.7543  0.6861  0.2983  0.4158  0.2573  0.2973

# %%
predicted_nb = predict_model(nb)
# Out:
#          Model  Accuracy    AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Naive Bayes     0.704  0.753  0.6847  0.2973  0.4145  0.2557  0.2955

# %%
predicted_nb_tuned = predict_model(tuned_nb)
# Out:
#          Model  Accuracy    AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Naive Bayes     0.704  0.753  0.6847  0.2973  0.4145  0.2557  0.2955

# %% [markdown]
# # The golden moment... put 10% sample test data through the models...

# %% [markdown]
# # Recombine test_features, test_target at first train/test/split
#  This "test" set was split BEFORE Oversampling. PyCaret takes the "train" from this split and splits it internally again. Since we have no control of how PyCaret does this we needed to do a train/test split before we input the training set into PyCaret. Now we will recombine the test_features and test_target into one new df

# %%
test_features.shape
# Out:
# (56960, 23)

# %%
test_target.shape
# Out:
# (56960,)

# %%
test_df = test_features.copy()

# %%
test_df['zeroBalCode'] = test_target

# %%
test_df.shape
# Out:
# (56960, 24)

# %%
totalTestCount = test_df.zeroBalCode.value_counts().sum()
posTestCount = test_df.zeroBalCode.value_counts()[1]
print('#############################################')
print('This "Test" set has not been oversamplied')
print(test_df.zeroBalCode.value_counts())
print(f'Positive samples are {round(posTestCount/totalTestCount*100,2)}%')
# Out:
# #############################################
# This "Test" set has not been oversamplied
# 0    48092
# 1     8868
# Name: zeroBalCode, dtype: int64
# Positive samples are 15.57%

# %% [markdown]
# ## Create Confusion Matrix output functions

# %%
def calc_confusion(row):
    if ((row['zeroBalCode'] == 0) & (row['Label'] == 0)):
        value = 'TrueNegative'
    elif ((row['zeroBalCode'] == 0) & (row['Label'] == 1)):
        value = 'FalsePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 1)):
        value = 'TruePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 0)):
        value = 'FalseNegative'
    else:
        value = 'Undefined'
    return value

# %%
def cM(df):
    print(f'           ##############################')
    print(f'           #             #              #')
    print(f'         0 #    {df["TrueNegative"]}     #     {df["FalsePositive"]}      #')
    print(f'  True     #             #              #')
    print(f'  Class    ##############################')
    print(f'           #             #              #')
    print(f'         1 #    {df["FalseNegative"]}      #     {df["TruePositive"]}      #')
    print(f'           #             #              #')
    print(f'           ##############################')
    print(f'                  0              1        ')
    print(f'                  Predicted Class           ')

# %%
def cMCalc():
    # 0 or 2 = Predict equals truth, 1 = Predict doesn't equal truth
    totalNegative = confusionMatrix['TrueNegative'] + confusionMatrix['FalseNegative']
    totalPositive = confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']
    total = totalNegative + totalPositive
    trueNegativePct = confusionMatrix['TrueNegative'] / total * 100
    falseNegativePct = confusionMatrix['FalseNegative'] / total * 100
    truePositivePct = confusionMatrix['TruePositive'] / total * 100
    falsePositivePct = confusionMatrix['FalsePositive'] / total * 100

    # Accuracy Calculation
    accuracy = (confusionMatrix['TruePositive'] + confusionMatrix['TrueNegative'])/(totalPositive + totalNegative)
    # Recall Calculation
    recall = (confusionMatrix['TruePositive']/(confusionMatrix['TruePositive'] + confusionMatrix['FalseNegative']))
    # Precision Calculation
    precision = (confusionMatrix['TruePositive']/(confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']))

    print(f'TrueNegative:  {round(trueNegativePct,2)}%')
    print(f'FalseNegative:  {round(falseNegativePct,2)}%')
    print(f'TruePositive:   {round(truePositivePct,2)}%')
    print(f'FalsePositive: {round(falsePositivePct,2)}%')
    print(f'#####################################################')
    print(f'Accuracy: {round(accuracy,2)*100}%   Recall: {round(recall,2)*100}%   Precision: {round(precision,2)*100}%')
    print(f'#####################################################')

# %% [markdown]
# # Evaluate Models

# %%
predictions = predict_model(final_nb, data=test_df)

# %%
pd.set_option('max_columns',None)
predictions.head()
# Out:
#    Unnamed: 0.1 origChannel          sellerName  origIntRate  origUPB  \
# 0       1176140           C  FLAGSTAR BANK, FSB        5.750   163000
# 1       1908158           C  CITIMORTGAGE, INC.        6.500   322000
# 2        901567           R               OTHER        5.940   132000
# 3        467540           B  FLAGSTAR BANK, FSB        6.875   166000
# 4       1468602           R               OTHER        5.500    64000
#
#    origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio loanPurp  \
# 0           360       95        95             2                43        P
# 1           360       80        95             2                48        P
# 2           360       97        97             1                44        P
# 3           360       80        80             2                43        C
# 4           300       89        89             2                 5        R
#
#   propState  zipCode  pMIperct  mortInsType  avgCreditScore  loanAge    mSA  \
# 0        MI      480      25.0            1             715       99  19820
# 1        NY      117       0.0            0             730      121  35620
# 2        IL      600      35.0            1             638      176  16980
# 3        UT      841       0.0            0             753       14  41620
# 4        NM      871      25.0            1             680       20  10740
#
#    fmacRateAvg  rateDiffAvg  rateDiffAvgPct  origYear  origMonth  zeroBalCode  \
# 0       5.2300       0.5200        0.099426      2003          6            0
# 1       6.6820      -0.1820       -0.027237      2006          6            0
# 2       5.8425       0.0975        0.016688      2003          2            1
# 3       6.9975      -0.1225       -0.017506      2002          1            0
# 4       5.4450       0.0550        0.010101      2004          3            0
#
#    Label   Score
# 0      1  0.7068
# 1      1  0.9894
# 2      1  0.7960
# 3      0  0.0001
# 4      0  0.4393

# %%
results = predictions[['zeroBalCode','Label','Score']]

# %%
predictions.Label.value_counts()
# Out:
# 0    42204
# 1    14756
# Name: Label, dtype: int64

# %%
results['Confusion'] = results.apply(calc_confusion, axis=1)

# %%
confusionMatrix = results.Confusion.value_counts().to_dict()

# %%
cM(confusionMatrix)
# Out:
#            ##############################
#            #             #              #
#          0 #    38222     #     9870      #
#   True     #             #              #
#   Class    ##############################
#            #             #              #
#          1 #    3982      #     4886      #
#            #             #              #
#            ##############################
#                   0              1
#                   Predicted Class

# %%
cMCalc()
# Out:
# TrueNegative:  67.1%
# FalseNegative:  6.99%
# TruePositive:   8.58%
# FalsePositive: 17.33%
# #####################################################
# Accuracy: 76.0%   Recall: 55.00000000000001%   Precision: 33.0%
# #####################################################

# %%
#save_model(final_nb, 'np.final5pct_092020')
