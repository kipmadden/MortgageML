# %% [markdown]
# # ML Foreclosure Binary Classification - EPOCH1 5% sample dataset
# Only "resolved" outcomes - Either paid off or default
#
#     target = zeroBalCode (set to object dtype)
#     Binary classification sets zeroBalCode to either "0" or "1" for the 7 possible outcomes
#
#     "0" = "Loan Success"
#         * 01 = Prepaid or Matured
#         * 06 = Repurchased
#         * 16 = Reperforming Loan Sale
#
#     "1" =  "Loan Failure" - Most likely loss of money (but not necessarily) one of below conditions:
#         * 02 = Third Party Sale
#         * 03 = Short Sale
#         * 09 = Deed-in-Lieu,REO
#         * 15 = Note Sale

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#!pip install pycaret
from imblearn.over_sampling import RandomOverSampler
from pycaret.classification import *
#from pycaret.regression import *
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importing the data - don't use *.ML.csv files!!!
# If you have *.MLReady.csv then [click here](#MLReady)

# %%
df=pd.read_csv("data/FM_Acq2_Perf_FMAC_EPOCH1_loanAge_5pct.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            id origChannel  \
# 0      349870        350665  381717688575           R
# 1     1426378       1427173  337308630846           C
# 2     1920339       1921134  930608058483           B
# 3      365256        366051  434312797171           R
# 4     1152850       1153645  546668906438           C
#
#                           sellerName  origIntRate  origUPB  origLoanTerm  \
# 0                              OTHER        6.875    94000           180
# 1                 CITIMORTGAGE, INC.        5.750   235000           360
# 2             SUNTRUST MORTGAGE INC.        6.875   168000           360
# 3  CAPITAL ONE, NATIONAL ASSOCIATION        5.750   210000           180
# 4                 CITIMORTGAGE, INC.        4.375   195000           180
#
#      origDate  origLTV  origCLTV  numBorrowers  origDebtIncRatio loanPurp  \
# 0  2001-08-01     69.0      69.0           1.0              62.0        C
# 1  2004-01-01     80.0      80.0           1.0              20.0        P
# 2  2006-07-01     72.0      90.0           1.0              39.0        R
# 3  2001-11-01     33.0      33.0           2.0              41.0        C
# 4  2003-06-01     53.0      53.0           1.0              25.0        R
#
#   propState  zipCode  pMIperct  mortInsType  bestCreditScore  \
# 0        NH       31       0.0          0.0            691.0
# 1        CA      945       0.0          0.0            785.0
# 2        OR      975       0.0          0.0            661.0
# 3        LA      704       0.0          0.0            742.0
# 4        WA      980       0.0          0.0            768.0
#
#    worstCreditScore  avgCreditScore  loanAge  monMatur    mSA  zeroBalCode  \
# 0             691.0           691.0       33     147.0  31700          1.0
# 1             785.0           785.0       13     347.0  41860          1.0
# 2             661.0           661.0       35     325.0  32780          9.0
# 3             735.0           738.5       70     110.0  35380          1.0
# 4             768.0           768.0      133      47.0  42660          1.0
#
#    deliqGood  deliqBad  deliqMax  fmacRateMax  fmacRateMin  fmacRateAvg  \
# 0         24         7       1.0         7.00         6.91       6.9500
# 1         11         1       1.0         5.87         5.64       5.7125
# 2         21        13      11.0         6.80         6.72       6.7625
# 3         68         2       1.0         7.02         6.45       6.6580
# 4        131         1       1.0         5.26         5.21       5.2300
#
#    fmacRateVolatility  fredRate  rateDiffAbove  rateDiffBelow  rateDiffAvg  \
# 0            0.013025      5.11         -0.125          0.035      -0.0750
# 1            0.040780      4.27         -0.120         -0.110       0.0375
# 2            0.011905      5.15          0.075         -0.155       0.1125
# 3            0.088372      4.24         -1.270          0.700      -0.9080
# 4            0.009597      3.37         -0.885          0.835      -0.8550
#
#    rateDiffAbovePct  rateDiffBelowPct  rateDiffAvgPct
# 0         -0.017857          0.005065       -0.010791
# 1         -0.020443         -0.019504        0.006565
# 2          0.011029         -0.023065        0.016636
# 3         -0.180912          0.108527       -0.136377
# 4         -0.168251          0.160269       -0.163480

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113918 entries, 0 to 113917
# Data columns (total 39 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          113918 non-null  int64
#  1   Unnamed: 0.1        113918 non-null  int64
#  2   id                  113918 non-null  int64
#  3   origChannel         113918 non-null  object
#  4   sellerName          113918 non-null  object
#  5   origIntRate         113918 non-null  float64
#  6   origUPB             113918 non-null  int64
#  7   origLoanTerm        113918 non-null  int64
#  8   origDate            113918 non-null  object
#  9   origLTV             113918 non-null  float64
#  10  origCLTV            113918 non-null  float64
#  11  numBorrowers        113918 non-null  float64
#  12  origDebtIncRatio    113918 non-null  float64
#  13  loanPurp            113918 non-null  object
#  14  propState           113918 non-null  object
#  15  zipCode             113918 non-null  int64
#  16  pMIperct            113918 non-null  float64
#  17  mortInsType         113918 non-null  float64
#  18  bestCreditScore     113918 non-null  float64
#  19  worstCreditScore    113918 non-null  float64
#  20  avgCreditScore      113918 non-null  float64
#  21  loanAge             113918 non-null  int64
#  22  monMatur            113838 non-null  float64
#  23  mSA                 113918 non-null  int64
#  24  zeroBalCode         113918 non-null  float64
#  25  deliqGood           113918 non-null  int64
#  26  deliqBad            113918 non-null  int64
#  27  deliqMax            113918 non-null  float64
#  28  fmacRateMax         113918 non-null  float64
#  29  fmacRateMin         113918 non-null  float64
#  30  fmacRateAvg         113918 non-null  float64
#  31  fmacRateVolatility  113918 non-null  float64
#  32  fredRate            113918 non-null  float64
#  33  rateDiffAbove       113918 non-null  float64
#  34  rateDiffBelow       113918 non-null  float64
#  35  rateDiffAvg         113918 non-null  float64
#  36  rateDiffAbovePct    113918 non-null  float64
#  37  rateDiffBelowPct    113918 non-null  float64
#  38  rateDiffAvgPct      113918 non-null  float64
# dtypes: float64(24), int64(10), object(5)
# memory usage: 33.9+ MB

# %% [markdown]
# ## Remove columns not involved in 'Foreclosure or Not' query

# %%
df.drop(['Unnamed: 0','id','fredRate',\
         'bestCreditScore','worstCreditScore','monMatur',\
         'deliqGood','deliqBad','deliqMax',\
        'fmacRateMax','fmacRateMin','fmacRateVolatility',\
        'rateDiffAbove','rateDiffBelow','rateDiffAbovePct','rateDiffBelowPct',\
        ],1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113918 entries, 0 to 113917
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0.1      113918 non-null  int64
#  1   origChannel       113918 non-null  object
#  2   sellerName        113918 non-null  object
#  3   origIntRate       113918 non-null  float64
#  4   origUPB           113918 non-null  int64
#  5   origLoanTerm      113918 non-null  int64
#  6   origDate          113918 non-null  object
#  7   origLTV           113918 non-null  float64
#  8   origCLTV          113918 non-null  float64
#  9   numBorrowers      113918 non-null  float64
#  10  origDebtIncRatio  113918 non-null  float64
#  11  loanPurp          113918 non-null  object
#  12  propState         113918 non-null  object
#  13  zipCode           113918 non-null  int64
#  14  pMIperct          113918 non-null  float64
#  15  mortInsType       113918 non-null  float64
#  16  avgCreditScore    113918 non-null  float64
#  17  loanAge           113918 non-null  int64
#  18  mSA               113918 non-null  int64
#  19  zeroBalCode       113918 non-null  float64
#  20  fmacRateAvg       113918 non-null  float64
#  21  rateDiffAvg       113918 non-null  float64
#  22  rateDiffAvgPct    113918 non-null  float64
# dtypes: float64(12), int64(6), object(5)
# memory usage: 20.0+ MB

# %% [markdown]
# ### Check if any columns have a null value

# %%
df.apply(lambda x: x.isnull().sum(), axis=0)
# Out:
# Unnamed: 0.1        0
# origChannel         0
# sellerName          0
# origIntRate         0
# origUPB             0
# origLoanTerm        0
# origDate            0
# origLTV             0
# origCLTV            0
# numBorrowers        0
# origDebtIncRatio    0
# loanPurp            0
# propState           0
# zipCode             0
# pMIperct            0
# mortInsType         0
# avgCreditScore      0
# loanAge             0
# mSA                 0
# zeroBalCode         0
# fmacRateAvg         0
# rateDiffAvg         0
# rateDiffAvgPct      0
# dtype: int64

# %% [markdown]
# ## Engineer originDate into Date features

# %%
df['origDate'] = pd.to_datetime(df['origDate'])

# %%
df['origYear'] = df['origDate'].dt.year
df['origMonth'] = df['origDate'].dt.month

# %%
df.drop(['origDate'],1,inplace=True)

# %%
df[['origYear','origMonth']].head()
# Out:
#    origYear  origMonth
# 0      2001          8
# 1      2004          1
# 2      2006          7
# 3      2001         11
# 4      2003          6

# %% [markdown]
# # Turn zero Balance Code Into binary "0" GOOD and "1" BAD

# %%
df.zeroBalCode.unique()
# Out:
# array([ 1.,  9.,  3.,  6.,  2., 16., 15.])

# %%
df['zeroBalCode'] = df.zeroBalCode.replace([1,6,16],0)
df['zeroBalCode'] = df.zeroBalCode.replace([9,3,2,15],1)

# %%
df.zeroBalCode.unique()
# Out:
# array([0., 1.])

# %%
#Checking datatypes of individual feature
df.head()
# Out:
#    Unnamed: 0.1 origChannel                         sellerName  origIntRate  \
# 0        350665           R                              OTHER        6.875
# 1       1427173           C                 CITIMORTGAGE, INC.        5.750
# 2       1921134           B             SUNTRUST MORTGAGE INC.        6.875
# 3        366051           R  CAPITAL ONE, NATIONAL ASSOCIATION        5.750
# 4       1153645           C                 CITIMORTGAGE, INC.        4.375
#
#    origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio  \
# 0    94000           180     69.0      69.0           1.0              62.0
# 1   235000           360     80.0      80.0           1.0              20.0
# 2   168000           360     72.0      90.0           1.0              39.0
# 3   210000           180     33.0      33.0           2.0              41.0
# 4   195000           180     53.0      53.0           1.0              25.0
#
#   loanPurp propState  zipCode  pMIperct  mortInsType  avgCreditScore  loanAge  \
# 0        C        NH       31       0.0          0.0           691.0       33
# 1        P        CA      945       0.0          0.0           785.0       13
# 2        R        OR      975       0.0          0.0           661.0       35
# 3        C        LA      704       0.0          0.0           738.5       70
# 4        R        WA      980       0.0          0.0           768.0      133
#
#      mSA  zeroBalCode  fmacRateAvg  rateDiffAvg  rateDiffAvgPct  origYear  \
# 0  31700          0.0       6.9500      -0.0750       -0.010791      2001
# 1  41860          0.0       5.7125       0.0375        0.006565      2004
# 2  32780          1.0       6.7625       0.1125        0.016636      2006
# 3  35380          0.0       6.6580      -0.9080       -0.136377      2001
# 4  42660          0.0       5.2300      -0.8550       -0.163480      2003
#
#    origMonth
# 0          8
# 1          1
# 2          7
# 3         11
# 4          6

# %% [markdown]
# # Review values for dates and slice (if needed) the timeframe you want

# %%
df.origYear.unique()
# Out:
# array([2001, 2004, 2006, 2003, 2007, 2002, 2005, 2000, 2008, 1999],
#       dtype=int64)

# %%
df['origMonth'].unique()
# Out:
# array([ 8,  1,  7, 11,  6,  5,  2,  4,  3, 10, 12,  9], dtype=int64)

# %%
df.head()
# Out:
#    Unnamed: 0.1 origChannel                         sellerName  origIntRate  \
# 0        350665           R                              OTHER        6.875
# 1       1427173           C                 CITIMORTGAGE, INC.        5.750
# 2       1921134           B             SUNTRUST MORTGAGE INC.        6.875
# 3        366051           R  CAPITAL ONE, NATIONAL ASSOCIATION        5.750
# 4       1153645           C                 CITIMORTGAGE, INC.        4.375
#
#    origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio  \
# 0    94000           180     69.0      69.0           1.0              62.0
# 1   235000           360     80.0      80.0           1.0              20.0
# 2   168000           360     72.0      90.0           1.0              39.0
# 3   210000           180     33.0      33.0           2.0              41.0
# 4   195000           180     53.0      53.0           1.0              25.0
#
#   loanPurp propState  zipCode  pMIperct  mortInsType  avgCreditScore  loanAge  \
# 0        C        NH       31       0.0          0.0           691.0       33
# 1        P        CA      945       0.0          0.0           785.0       13
# 2        R        OR      975       0.0          0.0           661.0       35
# 3        C        LA      704       0.0          0.0           738.5       70
# 4        R        WA      980       0.0          0.0           768.0      133
#
#      mSA  zeroBalCode  fmacRateAvg  rateDiffAvg  rateDiffAvgPct  origYear  \
# 0  31700          0.0       6.9500      -0.0750       -0.010791      2001
# 1  41860          0.0       5.7125       0.0375        0.006565      2004
# 2  32780          1.0       6.7625       0.1125        0.016636      2006
# 3  35380          0.0       6.6580      -0.9080       -0.136377      2001
# 4  42660          0.0       5.2300      -0.8550       -0.163480      2003
#
#    origMonth
# 0          8
# 1          1
# 2          7
# 3         11
# 4          6

# %% [markdown]
# # Coerce the column dtype (int in this case)

# %%
df = df.astype({'origLTV':'int','origCLTV':'int','numBorrowers':'int','origDebtIncRatio':'int',\
               'mortInsType':'int','loanAge':'int',\
               'avgCreditScore':'int','zeroBalCode':'int'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113918 entries, 0 to 113917
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0.1      113918 non-null  int64
#  1   origChannel       113918 non-null  object
#  2   sellerName        113918 non-null  object
#  3   origIntRate       113918 non-null  float64
#  4   origUPB           113918 non-null  int64
#  5   origLoanTerm      113918 non-null  int64
#  6   origLTV           113918 non-null  int32
#  7   origCLTV          113918 non-null  int32
#  8   numBorrowers      113918 non-null  int32
#  9   origDebtIncRatio  113918 non-null  int32
#  10  loanPurp          113918 non-null  object
#  11  propState         113918 non-null  object
#  12  zipCode           113918 non-null  int64
#  13  pMIperct          113918 non-null  float64
#  14  mortInsType       113918 non-null  int32
#  15  avgCreditScore    113918 non-null  int32
#  16  loanAge           113918 non-null  int32
#  17  mSA               113918 non-null  int64
#  18  zeroBalCode       113918 non-null  int32
#  19  fmacRateAvg       113918 non-null  float64
#  20  rateDiffAvg       113918 non-null  float64
#  21  rateDiffAvgPct    113918 non-null  float64
#  22  origYear          113918 non-null  int64
#  23  origMonth         113918 non-null  int64
# dtypes: float64(5), int32(8), int64(7), object(4)
# memory usage: 17.4+ MB

# %% [markdown]
# <a id='MLReady'></a>

# %% [markdown]
# # Train Test Split to create holdout dataset outside of PyCaret

# %%
good = df.zeroBalCode.value_counts()[0]
bad = df.zeroBalCode.value_counts()[1]
perct_bad = round(bad/(good + bad)*100,2)
print(f'We have {perct_bad}% Foreclosures in our dataset')
# Out:
# We have 15.32% Foreclosures in our dataset

# %%
from sklearn.model_selection import train_test_split

training_features, test_features, \
training_target, test_target, = train_test_split(
    df.drop(['zeroBalCode'], axis=1)
    , df['zeroBalCode']
    , test_size = .1
    , random_state=12
)

# %%
# Further split the training data into training/test
x_train, x_val, y_train, y_val = train_test_split(
    training_features
    , training_target
    , test_size = .1
    ,random_state=12
)

# %%
# For the training data, randomly sample 
# ros = RandomOverSampler(sampling_strategy='minority')
# x_train_res, y_train_res = ros.fit_sample(x_train, y_train)

# %%
print('#############################################')
print('Before oversampling: "Closed" crushes "Default" and causes issues:')
print(training_target.value_counts())
# print('')
# print('Before oversampling: "Closed" and "Default" are equal')
# print(y_train_res.value_counts())
# Out:
# #############################################
# Before oversampling: "Closed" crushes "Default" and causes issues:
# 0    86858
# 1    15668
# Name: zeroBalCode, dtype: int64

# %% [markdown]
# # Recombine X_train_res, y_train_res so PyCaret can deal with one df

# %%
y_train.shape
# Out:
# (92273,)

# %%
df = x_train.copy()

# %%
df['zeroBalCode'] = y_train

# %%
df.shape
# Out:
# (92273, 24)

# %% [markdown]
# # Review metrics last time before run (to have record of starting values)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92273 entries, 98148 to 64256
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0.1      92273 non-null  int64
#  1   origChannel       92273 non-null  object
#  2   sellerName        92273 non-null  object
#  3   origIntRate       92273 non-null  float64
#  4   origUPB           92273 non-null  int64
#  5   origLoanTerm      92273 non-null  int64
#  6   origLTV           92273 non-null  int32
#  7   origCLTV          92273 non-null  int32
#  8   numBorrowers      92273 non-null  int32
#  9   origDebtIncRatio  92273 non-null  int32
#  10  loanPurp          92273 non-null  object
#  11  propState         92273 non-null  object
#  12  zipCode           92273 non-null  int64
#  13  pMIperct          92273 non-null  float64
#  14  mortInsType       92273 non-null  int32
#  15  avgCreditScore    92273 non-null  int32
#  16  loanAge           92273 non-null  int32
#  17  mSA               92273 non-null  int64
#  18  fmacRateAvg       92273 non-null  float64
#  19  rateDiffAvg       92273 non-null  float64
#  20  rateDiffAvgPct    92273 non-null  float64
#  21  origYear          92273 non-null  int64
#  22  origMonth         92273 non-null  int64
#  23  zeroBalCode       92273 non-null  int32
# dtypes: float64(5), int32(8), int64(7), object(4)
# memory usage: 14.8+ MB

# %%
df.head()
# Out:
#        Unnamed: 0.1 origChannel                                 sellerName  \
# 98148        126705           R                        FLEET NATIONAL BANK
# 72477       1453913           R                    JPMORGAN CHASE BANK, NA
# 39555       1385125           C                                      OTHER
# 93412        936954           R                                      OTHER
# 37859        747615           B  JPMORGAN CHASE BANK, NATIONAL ASSOCIATION
#
#        origIntRate  origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  \
# 98148        7.250    80000           360       40        40             1
# 72477        5.750   275000           360       76        76             2
# 39555        6.250   125000           360       71        71             2
# 93412        6.000   143000           360       84        84             2
# 37859        5.625    82000           180       63        63             1
#
#        origDebtIncRatio loanPurp propState  zipCode  pMIperct  mortInsType  \
# 98148                49        P        NJ       73       0.0            0
# 72477                41        C        CA      917       0.0            0
# 39555                25        P        NJ       80       0.0            0
# 93412                33        R        PA      170      12.0            1
# 37859                20        C        SC      293       0.0            0
#
#        avgCreditScore  loanAge    mSA  fmacRateAvg  rateDiffAvg  \
# 98148             741      122  35620       7.0325       0.2175
# 72477             677      108  40140       5.6350       0.1150
# 39555             778       85  35620       5.8760       0.3740
# 93412             722      108  25420       5.7450       0.2550
# 37859             646      161  43900       6.0680      -0.4430
#
#        rateDiffAvgPct  origYear  origMonth  zeroBalCode
# 98148        0.030928      2001          1            0
# 72477        0.020408      2004          2            0
# 39555        0.063649      2003         12            0
# 93412        0.044386      2003          3            0
# 37859       -0.073006      2002         11            0

# %% [markdown]
# # Pycaret - Setup with categorical definition

# %% [markdown]
# ### Use complex setup

# %%
model_setup = setup(
    df
    , target = 'zeroBalCode' # PyCaret will list this as "Label"
    , normalize = True
    , transformation = False
    , pca = False 
    , ignore_low_variance = False # Variance is calculated using the ratio of unique values to the number of samples, and the ratio of the most common value to the frequency of the second most common value. 
    , ignore_features = None
    , handle_unknown_categorical = True
    , remove_outliers = True
    , remove_multicollinearity = False
    , polynomial_features = False
    , trigonometry_features = False
    , feature_selection = False
    , feature_interaction = False
    , fix_imbalance = False
    , silent = True
    , profile = False
    # outliers from the training data are removed using PCA linear dimensionality reduction using the Singular Value Decomposition technique.
    , bin_numeric_features = [
        'avgCreditScore'
        ] # Set to True to bin numerics using K Means
    , categorical_features = [
         'origChannel'
        , 'loanPurp'
        , 'origYear'
        , 'origMonth'
        , 'mortInsType'
        , 'origLoanTerm'
        ]
    , high_cardinality_features = [
         'propState'
        , 'sellerName'
        , 'mSA'
        , 'zipCode'
    ]
    , high_cardinality_method = 'clustering'
    , numeric_features = [
        'origIntRate'
        , 'numBorrowers'
        , 'origUPB'
        , 'origLTV'
        , 'origCLTV'
        , 'pMIperct'
        , 'loanAge'
        , 'origDebtIncRatio'
        , 'avgCreditScore'
        , 'rateDiffAvg'
        , 'rateDiffAvgPct'
        , 'fmacRateAvg'
    ]
)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# #T_b89f385c_fc37_11ea_b5fa_309c234564f5row8_col1,#T_b89f385c_fc37_11ea_b5fa_309c234564f5row15_col1,#T_b89f385c_fc37_11ea_b5fa_309c234564f5row25_col1,#T_b89f385c_fc37_11ea_b5fa_309c234564f5row26_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_b89f385c_fc37_11ea_b5fa_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b89f385c_fc37_11ea_b5fa_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b89f385c_fc37_11ea_b5fa_309c234564f5row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T
#         }#T_b99db89a_fc38_11ea_b66d_309c234564f5row0_col3,#T_b99db89a_fc38_11ea_b66d_309c234564f5row0_col5,#T_b99db89a_fc38_11ea_b66d_309c234564f5row5_col2,#T_b99db89a_fc38_11ea_b66d_309c234564f5row5_col6,#T_b99db89a_fc38_11ea_b66d_309c234564f5row5_col7,#T_b99db89a_fc38_11ea_b66d_309c234564f5row6_col1,#T_b99db89a_fc38_11ea_b66d_309c234564f5row6_col4{
#             background-color:  yellow;
#             text-align:  left;
#         }#T_b99db89a_fc38_11ea_b66d_309c234564f5row0_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row1_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row2_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row3_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row4_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row5_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row6_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row7_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row8_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row9_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row10_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row11_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row12_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row13_col8,#T_b99db89a_fc38_11ea_b66d_309c234564f5row14_col8{
#             background-color:  lightgrey;
#             text-align:  left;
#         }</style><table id="T_b99db89a_fc38_11ea_b66d_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b99db89a_fc38_11ea_b66d_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b99db89a_fc38_11ea_b66d_309c234564f5row0_col0" class="data row0 col0" >Naive Bayes</td>
#                         <td id="T_b99db89a_fc38_11ea_b66d_309c234564f5row0_col1" class="data row0 col1" >0.5794</td>
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ## Create models

# %% [markdown]
# ### NB Classifier

# %%
nb = create_model('nb', fold=10)
# Out:
# <style  type="text/css" >
# #T_c1324b42_fc38_11ea_9165_309c234564f5row10_col0,#T_c1324b42_fc38_11ea_9165_309c234564f5row10_col1,#T_c1324b42_fc38_11ea_9165_309c234564f5row10_col2,#T_c1324b42_fc38_11ea_9165_309c234564f5row10_col3,#T_c1324b42_fc38_11ea_9165_309c234564f5row10_col4,#T_c1324b42_fc38_11ea_9165_309c234564f5row10_col5,#T_c1324b42_fc38_11ea_9165_309c234564f5row10_col6{
#             background:  yellow;
#         }</style><table id="T_c1324b42_fc38_11ea_9165_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1324b42_fc38_11ea_9165_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row0_col0" class="data row0 col0" >0.5674</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row0_col1" class="data row0 col1" >0.7422</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row0_col2" class="data row0 col2" >0.8185</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row0_col3" class="data row0 col3" >0.2346</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row0_col4" class="data row0 col4" >0.3647</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row0_col5" class="data row0 col5" >0.1686</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row0_col6" class="data row0 col6" >0.2450</td>
#             </tr>
#             <tr>
#                         <th id="T_c1324b42_fc38_11ea_9165_309c234564f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row1_col0" class="data row1 col0" >0.5642</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row1_col1" class="data row1 col1" >0.7493</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row1_col2" class="data row1 col2" >0.8183</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row1_col3" class="data row1 col3" >0.2330</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row1_col4" class="data row1 col4" >0.3627</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row1_col5" class="data row1 col5" >0.1659</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row1_col6" class="data row1 col6" >0.2423</td>
#             </tr>
#             <tr>
#                         <th id="T_c1324b42_fc38_11ea_9165_309c234564f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row2_col0" class="data row2 col0" >0.5652</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row2_col1" class="data row2 col1" >0.7595</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row2_col2" class="data row2 col2" >0.8344</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row2_col3" class="data row2 col3" >0.2359</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row2_col4" class="data row2 col4" >0.3678</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row2_col5" class="data row2 col5" >0.1721</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row2_col6" class="data row2 col6" >0.2528</td>
#             </tr>
#             <tr>
#                         <th id="T_c1324b42_fc38_11ea_9165_309c234564f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row3_col0" class="data row3 col0" >0.5642</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row3_col1" class="data row3 col1" >0.7388</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row3_col2" class="data row3 col2" >0.7925</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row3_col3" class="data row3 col3" >0.2290</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row3_col4" class="data row3 col4" >0.3554</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row3_col5" class="data row3 col5" >0.1571</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row3_col6" class="data row3 col6" >0.2268</td>
#             </tr>
#             <tr>
#                         <th id="T_c1324b42_fc38_11ea_9165_309c234564f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row4_col0" class="data row4 col0" >0.5596</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row4_col1" class="data row4 col1" >0.7564</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row4_col2" class="data row4 col2" >0.8376</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row4_col3" class="data row4 col3" >0.2339</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row4_col4" class="data row4 col4" >0.3657</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row4_col5" class="data row4 col5" >0.1688</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row4_col6" class="data row4 col6" >0.2502</td>
#             </tr>
#             <tr>
#                         <th id="T_c1324b42_fc38_11ea_9165_309c234564f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row5_col0" class="data row5 col0" >0.5678</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row5_col1" class="data row5 col1" >0.7568</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row5_col2" class="data row5 col2" >0.8398</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row5_col3" class="data row5 col3" >0.2378</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row5_col4" class="data row5 col4" >0.3707</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row5_col5" class="data row5 col5" >0.1760</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row5_col6" class="data row5 col6" >0.2581</td>
#             </tr>
#             <tr>
#                         <th id="T_c1324b42_fc38_11ea_9165_309c234564f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row6_col0" class="data row6 col0" >0.5610</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row6_col1" class="data row6 col1" >0.7603</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row6_col2" class="data row6 col2" >0.8387</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row6_col3" class="data row6 col3" >0.2347</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row6_col4" class="data row6 col4" >0.3667</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row6_col5" class="data row6 col5" >0.1702</td>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row6_col6" class="data row6 col6" >0.2519</td>
#             </tr>
#             <tr>
#                         <th id="T_c1324b42_fc38_11ea_9165_309c234564f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c1324b42_fc38_11ea_9165_309c234564f5row7_co

# %% [markdown]
# ## Evaluate Models

# %%
evaluate_model(nb)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ## Tune Model

# %%
tuned_nb = tune_model(nb, optimize = 'Recall')
# Out:
# <style  type="text/css" >
# #T_e5fc1700_fc38_11ea_934a_309c234564f5row10_col0,#T_e5fc1700_fc38_11ea_934a_309c234564f5row10_col1,#T_e5fc1700_fc38_11ea_934a_309c234564f5row10_col2,#T_e5fc1700_fc38_11ea_934a_309c234564f5row10_col3,#T_e5fc1700_fc38_11ea_934a_309c234564f5row10_col4,#T_e5fc1700_fc38_11ea_934a_309c234564f5row10_col5,#T_e5fc1700_fc38_11ea_934a_309c234564f5row10_col6{
#             background:  yellow;
#         }</style><table id="T_e5fc1700_fc38_11ea_934a_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e5fc1700_fc38_11ea_934a_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row0_col0" class="data row0 col0" >0.6519</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row0_col1" class="data row0 col1" >0.7422</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row0_col2" class="data row0 col2" >0.7454</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row0_col3" class="data row0 col3" >0.2676</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row0_col4" class="data row0 col4" >0.3939</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row0_col5" class="data row0 col5" >0.2197</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row0_col6" class="data row0 col6" >0.2765</td>
#             </tr>
#             <tr>
#                         <th id="T_e5fc1700_fc38_11ea_934a_309c234564f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row1_col0" class="data row1 col0" >0.6494</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row1_col1" class="data row1 col1" >0.7493</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row1_col2" class="data row1 col2" >0.7452</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row1_col3" class="data row1 col3" >0.2658</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row1_col4" class="data row1 col4" >0.3919</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row1_col5" class="data row1 col5" >0.2169</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row1_col6" class="data row1 col6" >0.2739</td>
#             </tr>
#             <tr>
#                         <th id="T_e5fc1700_fc38_11ea_934a_309c234564f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row2_col0" class="data row2 col0" >0.6553</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row2_col1" class="data row2 col1" >0.7595</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row2_col2" class="data row2 col2" >0.7753</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row2_col3" class="data row2 col3" >0.2745</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row2_col4" class="data row2 col4" >0.4054</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row2_col5" class="data row2 col5" >0.2339</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row2_col6" class="data row2 col6" >0.2965</td>
#             </tr>
#             <tr>
#                         <th id="T_e5fc1700_fc38_11ea_934a_309c234564f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row3_col0" class="data row3 col0" >0.6454</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row3_col1" class="data row3 col1" >0.7388</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row3_col2" class="data row3 col2" >0.7290</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row3_col3" class="data row3 col3" >0.2606</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row3_col4" class="data row3 col4" >0.3839</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row3_col5" class="data row3 col5" >0.2068</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row3_col6" class="data row3 col6" >0.2608</td>
#             </tr>
#             <tr>
#                         <th id="T_e5fc1700_fc38_11ea_934a_309c234564f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row4_col0" class="data row4 col0" >0.6460</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row4_col1" class="data row4 col1" >0.7564</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row4_col2" class="data row4 col2" >0.7548</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row4_col3" class="data row4 col3" >0.2653</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row4_col4" class="data row4 col4" >0.3926</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row4_col5" class="data row4 col5" >0.2170</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row4_col6" class="data row4 col6" >0.2762</td>
#             </tr>
#             <tr>
#                         <th id="T_e5fc1700_fc38_11ea_934a_309c234564f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row5_col0" class="data row5 col0" >0.6509</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row5_col1" class="data row5 col1" >0.7568</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row5_col2" class="data row5 col2" >0.7634</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row5_col3" class="data row5 col3" >0.2698</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row5_col4" class="data row5 col4" >0.3987</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row5_col5" class="data row5 col5" >0.2251</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row5_col6" class="data row5 col6" >0.2857</td>
#             </tr>
#             <tr>
#                         <th id="T_e5fc1700_fc38_11ea_934a_309c234564f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row6_col0" class="data row6 col0" >0.6488</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row6_col1" class="data row6 col1" >0.7603</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row6_col2" class="data row6 col2" >0.7570</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row6_col3" class="data row6 col3" >0.2674</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row6_col4" class="data row6 col4" >0.3952</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row6_col5" class="data row6 col5" >0.2206</td>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row6_col6" class="data row6 col6" >0.2800</td>
#             </tr>
#             <tr>
#                         <th id="T_e5fc1700_fc38_11ea_934a_309c234564f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e5fc1700_fc38_11ea_934a_309c234564f5row7_co

# %%
evaluate_model(tuned_nb)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
final_nb = finalize_model(tuned_nb)

# %%
evaluate_model(final_nb)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# # Predict models

# %%
predicted_final_nb = predict_model(final_nb)
# Out:
#          Model  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Naive Bayes    0.6578  0.7507  0.7374  0.2699  0.3952  0.2227  0.2774

# %%
predicted_nb = predict_model(nb)
# Out:
#          Model  Accuracy     AUC  Recall  Prec.      F1   Kappa     MCC
# 0  Naive Bayes    0.5705  0.7477  0.8262  0.237  0.3684  0.1737  0.2521

# %%
predicted_nb_tuned = predict_model(tuned_nb)
# Out:
#          Model  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Naive Bayes    0.6524  0.7477  0.7389  0.2667  0.3919  0.2176  0.2731

# %% [markdown]
# # The golden moment... put 10% sample test data through the models...

# %% [markdown]
# # Recombine test_features, test_target at first train/test/split
#  This "test" set was split BEFORE Oversampling. PyCaret takes the "train" from this split and splits it internally again. Since we have no control of how PyCaret does this we needed to do a train/test split before we input the training set into PyCaret. Now we will recombine the test_features and test_target into one new df

# %%
test_features.shape
# Out:
# (11392, 23)

# %%
test_target.shape
# Out:
# (11392,)

# %%
test_df = test_features.copy()

# %%
test_df['zeroBalCode'] = test_target

# %%
test_df.shape
# Out:
# (11392, 24)

# %%
totalTestCount = test_df.zeroBalCode.value_counts().sum()
posTestCount = test_df.zeroBalCode.value_counts()[1]
print('#############################################')
print('This "Test" set has not been oversamplied')
print(test_df.zeroBalCode.value_counts())
print(f'Positive samples are {round(posTestCount/totalTestCount*100,2)}%')
# Out:
# #############################################
# This "Test" set has not been oversamplied
# 0    9612
# 1    1780
# Name: zeroBalCode, dtype: int64
# Positive samples are 15.62%

# %% [markdown]
# ## Create Confusion Matrix output functions

# %%
def calc_confusion(row):
    if ((row['zeroBalCode'] == 0) & (row['Label'] == 0)):
        value = 'TrueNegative'
    elif ((row['zeroBalCode'] == 0) & (row['Label'] == 1)):
        value = 'FalsePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 1)):
        value = 'TruePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 0)):
        value = 'FalseNegative'
    else:
        value = 'Undefined'
    return value

# %%
def cM(df):
    print(f'           ##############################')
    print(f'           #             #              #')
    print(f'         0 #    {df["TrueNegative"]}     #     {df["FalsePositive"]}      #')
    print(f'  True     #             #              #')
    print(f'  Class    ##############################')
    print(f'           #             #              #')
    print(f'         1 #    {df["FalseNegative"]}      #     {df["TruePositive"]}      #')
    print(f'           #             #              #')
    print(f'           ##############################')
    print(f'                  0              1        ')
    print(f'                  Predicted Class           ')

# %%
def cMCalc():
    # 0 or 2 = Predict equals truth, 1 = Predict doesn't equal truth
    totalNegative = confusionMatrix['TrueNegative'] + confusionMatrix['FalseNegative']
    totalPositive = confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']
    total = totalNegative + totalPositive
    trueNegativePct = confusionMatrix['TrueNegative'] / total * 100
    falseNegativePct = confusionMatrix['FalseNegative'] / total * 100
    truePositivePct = confusionMatrix['TruePositive'] / total * 100
    falsePositivePct = confusionMatrix['FalsePositive'] / total * 100

    # Accuracy Calculation
    accuracy = (confusionMatrix['TruePositive'] + confusionMatrix['TrueNegative'])/(totalPositive + totalNegative)
    # Recall Calculation
    recall = (confusionMatrix['TruePositive']/(confusionMatrix['TruePositive'] + confusionMatrix['FalseNegative']))
    # Precision Calculation
    precision = (confusionMatrix['TruePositive']/(confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']))

    print(f'TrueNegative:  {round(trueNegativePct,2)}%')
    print(f'FalseNegative:  {round(falseNegativePct,2)}%')
    print(f'TruePositive:   {round(truePositivePct,2)}%')
    print(f'FalsePositive: {round(falsePositivePct,2)}%')
    print(f'#####################################################')
    print(f'Accuracy: {round(accuracy,2)*100}%   Recall: {round(recall,2)*100}%   Precision: {round(precision,2)*100}%')
    print(f'#####################################################')

# %% [markdown]
# # Evaluate Models

# %%
predictions = predict_model(final_nb, data=test_df)

# %%
pd.set_option('max_columns',None)
predictions.head()
# Out:
#    Unnamed: 0.1 origChannel               sellerName  origIntRate  origUPB  \
# 0        741073           C  JPMORGAN CHASE BANK, NA        6.250   146000
# 1       1113069           R  JPMORGAN CHASE BANK, NA        5.750    94000
# 2       1513812           C       CITIMORTGAGE, INC.        5.500    53000
# 3       1747659           C       GMAC MORTGAGE, LLC        5.500   134000
# 4       1370047           C    BANK OF AMERICA, N.A.        5.875   101000
#
#    origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio loanPurp  \
# 0           360       90        90             1                44        R
# 1           360       80        80             1                26        C
# 2           180       15        15             2                50        C
# 3           360       67        67             1                62        P
# 4           360       66        66             1                34        C
#
#   propState  zipCode  pMIperct  mortInsType  avgCreditScore  loanAge    mSA  \
# 0        UT      844      25.0            1             694       66  36260
# 1        LA      701       0.0            0             689       33  35380
# 2        CT       68       0.0            0             598      175  14860
# 3        KY      405       0.0            0             718       62  30460
# 4        CA      959       0.0            0             649       11  17020
#
#    fmacRateAvg  rateDiffAvg  rateDiffAvgPct  origYear  origMonth  zeroBalCode  \
# 0       6.1125       0.1375        0.022495      2002         10            1
# 1       5.4840       0.2660        0.048505      2003          5            0
# 2       5.8300      -0.3300       -0.056604      2004          4            0
# 3       5.6950      -0.1950       -0.034241      2005          7            0
# 4       5.9325      -0.0575       -0.009692      2003         11            0
#
#    Label   Score
# 0      1  0.7800
# 1      0  0.2245
# 2      0  0.0000
# 3      1  0.8961
# 4      0  0.0679

# %%
results = predictions[['zeroBalCode','Label','Score']]

# %%
predictions.Label.value_counts()
# Out:
# 0    7830
# 1    3562
# Name: Label, dtype: int64

# %%
results['Confusion'] = results.apply(calc_confusion, axis=1)

# %%
confusionMatrix = results.Confusion.value_counts().to_dict()

# %%
cM(confusionMatrix)
# Out:
#            ##############################
#            #             #              #
#          0 #    7130     #     2482      #
#   True     #             #              #
#   Class    ##############################
#            #             #              #
#          1 #    700      #     1080      #
#            #             #              #
#            ##############################
#                   0              1
#                   Predicted Class

# %%
cMCalc()
# Out:
# TrueNegative:  62.59%
# FalseNegative:  6.14%
# TruePositive:   9.48%
# FalsePositive: 21.79%
# #####################################################
# Accuracy: 72.0%   Recall: 61.0%   Precision: 30.0%
# #####################################################

# %%
#save_model(final_nb, 'np.final5pct_092020')
