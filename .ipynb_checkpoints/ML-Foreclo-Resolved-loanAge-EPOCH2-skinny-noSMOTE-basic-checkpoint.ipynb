# %% [markdown]
# # ML Foreclosure Binary Classification - EPOCH2 sample dataset
# Only "resolved" outcomes - Either paid off or default
#
#     target = zeroBalCode (set to object dtype)
#     Binary classification sets zeroBalCode to either "0" or "1" for the 7 possible outcomes
#
#     "0" = "Loan Success"
#         * 01 = Prepaid or Matured
#         * 06 = Repurchased
#         * 16 = Reperforming Loan Sale
#
#     "1" =  "Loan Failure" - Most likely loss of money (but not necessarily) one of below conditions:
#         * 02 = Third Party Sale
#         * 03 = Short Sale
#         * 09 = Deed-in-Lieu,REO
#         * 15 = Note Sale

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#!pip install pycaret
from imblearn.over_sampling import RandomOverSampler
from pycaret.classification import *
#from pycaret.regression import *
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importing the data - don't use *.ML.csv files!!!
# If you have *.MLReady.csv then [click here](#MLReady)

# %%
df=pd.read_csv("data/FM_Acq2_Perf_FMAC_EPOCH2_loanAge.csv")
df.head()
# Out:
#    Unnamed: 0            id origChannel  \
# 0     2307189  100012021911           C
# 1     2307190  100209956357           B
# 2     2307191  100250194205           R
# 3     2307192  100366856388           R
# 4     2307193  100392775700           C
#
#                                   sellerName  origIntRate  origUPB  \
# 0  JPMORGAN CHASE BANK, NATIONAL ASSOCIATION        4.375   417000
# 1                     WELLS FARGO BANK, N.A.        5.125   348000
# 2                                      OTHER        5.125    65000
# 3                                      OTHER        4.875    37000
# 4                      BANK OF AMERICA, N.A.        4.625   195000
#
#    origLoanTerm    origDate  origLTV  origCLTV  numBorrowers  \
# 0           180  2009-02-01     27.0      27.0           2.0
# 1           360  2009-02-01     87.0      87.0           1.0
# 2           360  2009-02-01     95.0      95.0           1.0
# 3           360  2009-02-01     55.0      55.0           1.0
# 4           360  2009-02-01     52.0      52.0           2.0
#
#    origDebtIncRatio loanPurp propState  zipCode  pMIperct  mortInsType  \
# 0              14.0        R        NJ       76       0.0          0.0
# 1              50.0        R        VT       51      25.0          1.0
# 2              17.0        P        IL      613      25.0          1.0
# 3              23.0        P        IL      626       0.0          0.0
# 4              54.0        C        NJ       82       0.0          0.0
#
#    bestCreditScore  worstCreditScore  avgCreditScore  loanAge  monMatur  \
# 0            759.0             756.0           757.5       43     137.0
# 1            689.0             689.0           689.0       90     293.0
# 2            738.0             738.0           738.0       38     322.0
# 3            777.0             777.0           777.0       48     312.0
# 4            810.0             703.0           756.5       69     291.0
#
#      mSA  zeroBalCode  deliqGood  deliqBad  deliqMax  fmacRateMax  \
# 0  35620          1.0         39         4       1.0         5.25
# 1      0          9.0         75        15       7.0         5.25
# 2      0          9.0         18        20      16.0         5.25
# 3      0          6.0         44         4       5.0         5.25
# 4  12100          1.0         68         1       1.0         5.25
#
#    fmacRateMin  fmacRateAvg  fmacRateVolatility  fredRate  rateDiffAbove  \
# 0         5.04         5.13            0.041667      2.87         -0.875
# 1         5.04         5.13            0.041667      2.87         -0.125
# 2         5.04         5.13            0.041667      2.87         -0.125
# 3         5.04         5.13            0.041667      2.87         -0.375
# 4         5.04         5.13            0.041667      2.87         -0.625
#
#    rateDiffBelow  rateDiffAvg  rateDiffAbovePct  rateDiffBelowPct  \
# 0          0.665       -0.755         -0.166667          0.131944
# 1         -0.085       -0.005         -0.023810         -0.016865
# 2         -0.085       -0.005         -0.023810         -0.016865
# 3          0.165       -0.255         -0.071429          0.032738
# 4          0.415       -0.505         -0.119048          0.082341
#
#    rateDiffAvgPct
# 0       -0.147173
# 1       -0.000975
# 2       -0.000975
# 3       -0.049708
# 4       -0.098441

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240948 entries, 0 to 240947
# Data columns (total 38 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          240948 non-null  int64
#  1   id                  240948 non-null  int64
#  2   origChannel         240948 non-null  object
#  3   sellerName          240948 non-null  object
#  4   origIntRate         240948 non-null  float64
#  5   origUPB             240948 non-null  int64
#  6   origLoanTerm        240948 non-null  int64
#  7   origDate            240948 non-null  object
#  8   origLTV             240948 non-null  float64
#  9   origCLTV            240948 non-null  float64
#  10  numBorrowers        240948 non-null  float64
#  11  origDebtIncRatio    240948 non-null  float64
#  12  loanPurp            240948 non-null  object
#  13  propState           240948 non-null  object
#  14  zipCode             240948 non-null  int64
#  15  pMIperct            240948 non-null  float64
#  16  mortInsType         240948 non-null  float64
#  17  bestCreditScore     240948 non-null  float64
#  18  worstCreditScore    240948 non-null  float64
#  19  avgCreditScore      240948 non-null  float64
#  20  loanAge             240948 non-null  int64
#  21  monMatur            240948 non-null  float64
#  22  mSA                 240948 non-null  int64
#  23  zeroBalCode         240948 non-null  float64
#  24  deliqGood           240948 non-null  int64
#  25  deliqBad            240948 non-null  int64
#  26  deliqMax            240948 non-null  float64
#  27  fmacRateMax         240948 non-null  float64
#  28  fmacRateMin         240948 non-null  float64
#  29  fmacRateAvg         240948 non-null  float64
#  30  fmacRateVolatility  240948 non-null  float64
#  31  fredRate            240948 non-null  float64
#  32  rateDiffAbove       240948 non-null  float64
#  33  rateDiffBelow       240948 non-null  float64
#  34  rateDiffAvg         240948 non-null  float64
#  35  rateDiffAbovePct    240948 non-null  float64
#  36  rateDiffBelowPct    240948 non-null  float64
#  37  rateDiffAvgPct      240948 non-null  float64
# dtypes: float64(24), int64(9), object(5)
# memory usage: 69.9+ MB

# %% [markdown]
# ## Remove columns not involved in 'Foreclosure or Not' query

# %%
df.drop(['Unnamed: 0','id','fredRate',\
         'bestCreditScore','worstCreditScore','monMatur',\
         'deliqGood','deliqBad','deliqMax',\
        'fmacRateMax','fmacRateMin','fmacRateVolatility',\
        'rateDiffAbove','rateDiffBelow','rateDiffAbovePct','rateDiffBelowPct',\
        ],1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240948 entries, 0 to 240947
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   origChannel       240948 non-null  object
#  1   sellerName        240948 non-null  object
#  2   origIntRate       240948 non-null  float64
#  3   origUPB           240948 non-null  int64
#  4   origLoanTerm      240948 non-null  int64
#  5   origDate          240948 non-null  object
#  6   origLTV           240948 non-null  float64
#  7   origCLTV          240948 non-null  float64
#  8   numBorrowers      240948 non-null  float64
#  9   origDebtIncRatio  240948 non-null  float64
#  10  loanPurp          240948 non-null  object
#  11  propState         240948 non-null  object
#  12  zipCode           240948 non-null  int64
#  13  pMIperct          240948 non-null  float64
#  14  mortInsType       240948 non-null  float64
#  15  avgCreditScore    240948 non-null  float64
#  16  loanAge           240948 non-null  int64
#  17  mSA               240948 non-null  int64
#  18  zeroBalCode       240948 non-null  float64
#  19  fmacRateAvg       240948 non-null  float64
#  20  rateDiffAvg       240948 non-null  float64
#  21  rateDiffAvgPct    240948 non-null  float64
# dtypes: float64(12), int64(5), object(5)
# memory usage: 40.4+ MB

# %% [markdown]
# ### Check if any columns have a null value

# %%
df.apply(lambda x: x.isnull().sum(), axis=0)
# Out:
# origChannel         0
# sellerName          0
# origIntRate         0
# origUPB             0
# origLoanTerm        0
# origDate            0
# origLTV             0
# origCLTV            0
# numBorrowers        0
# origDebtIncRatio    0
# loanPurp            0
# propState           0
# zipCode             0
# pMIperct            0
# mortInsType         0
# avgCreditScore      0
# loanAge             0
# mSA                 0
# zeroBalCode         0
# fmacRateAvg         0
# rateDiffAvg         0
# rateDiffAvgPct      0
# dtype: int64

# %% [markdown]
# ## Engineer originDate into Date features

# %%
df['origDate'] = pd.to_datetime(df['origDate'])

# %%
df['origYear'] = df['origDate'].dt.year
df['origMonth'] = df['origDate'].dt.month

# %%
df.drop(['origDate'],1,inplace=True)

# %%
df[['origYear','origMonth']].head()
# Out:
#    origYear  origMonth
# 0      2009          2
# 1      2009          2
# 2      2009          2
# 3      2009          2
# 4      2009          2

# %% [markdown]
# # Turn zero Balance Code Into binary "0" GOOD and "1" BAD

# %%
df.zeroBalCode.unique()
# Out:
# array([ 1.,  9.,  6., 15.,  3., 16.,  2.])

# %%
df['zeroBalCode'] = df.zeroBalCode.replace([1,6,16],0)
df['zeroBalCode'] = df.zeroBalCode.replace([9,3,2,15],1)

# %%
df.zeroBalCode.unique()
# Out:
# array([0., 1.])

# %%
#Checking datatypes of individual feature
df.head()
# Out:
#   origChannel                                 sellerName  origIntRate  \
# 0           C  JPMORGAN CHASE BANK, NATIONAL ASSOCIATION        4.375
# 1           B                     WELLS FARGO BANK, N.A.        5.125
# 2           R                                      OTHER        5.125
# 3           R                                      OTHER        4.875
# 4           C                      BANK OF AMERICA, N.A.        4.625
#
#    origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio  \
# 0   417000           180     27.0      27.0           2.0              14.0
# 1   348000           360     87.0      87.0           1.0              50.0
# 2    65000           360     95.0      95.0           1.0              17.0
# 3    37000           360     55.0      55.0           1.0              23.0
# 4   195000           360     52.0      52.0           2.0              54.0
#
#   loanPurp propState  zipCode  pMIperct  mortInsType  avgCreditScore  loanAge  \
# 0        R        NJ       76       0.0          0.0           757.5       43
# 1        R        VT       51      25.0          1.0           689.0       90
# 2        P        IL      613      25.0          1.0           738.0       38
# 3        P        IL      626       0.0          0.0           777.0       48
# 4        C        NJ       82       0.0          0.0           756.5       69
#
#      mSA  zeroBalCode  fmacRateAvg  rateDiffAvg  rateDiffAvgPct  origYear  \
# 0  35620          0.0         5.13       -0.755       -0.147173      2009
# 1      0          1.0         5.13       -0.005       -0.000975      2009
# 2      0          1.0         5.13       -0.005       -0.000975      2009
# 3      0          0.0         5.13       -0.255       -0.049708      2009
# 4  12100          0.0         5.13       -0.505       -0.098441      2009
#
#    origMonth
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %% [markdown]
# # Review values for dates and slice (if needed) the timeframe you want

# %%
df.origYear.unique()
# Out:
# array([2009, 2010, 2011, 2012, 2013], dtype=int64)

# %%
df['origMonth'].unique()
# Out:
# array([ 2,  3,  5,  4,  6,  7,  8,  9, 10, 11, 12,  1], dtype=int64)

# %%
df.head()
# Out:
#   origChannel                                 sellerName  origIntRate  \
# 0           C  JPMORGAN CHASE BANK, NATIONAL ASSOCIATION        4.375
# 1           B                     WELLS FARGO BANK, N.A.        5.125
# 2           R                                      OTHER        5.125
# 3           R                                      OTHER        4.875
# 4           C                      BANK OF AMERICA, N.A.        4.625
#
#    origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio  \
# 0   417000           180     27.0      27.0           2.0              14.0
# 1   348000           360     87.0      87.0           1.0              50.0
# 2    65000           360     95.0      95.0           1.0              17.0
# 3    37000           360     55.0      55.0           1.0              23.0
# 4   195000           360     52.0      52.0           2.0              54.0
#
#   loanPurp propState  zipCode  pMIperct  mortInsType  avgCreditScore  loanAge  \
# 0        R        NJ       76       0.0          0.0           757.5       43
# 1        R        VT       51      25.0          1.0           689.0       90
# 2        P        IL      613      25.0          1.0           738.0       38
# 3        P        IL      626       0.0          0.0           777.0       48
# 4        C        NJ       82       0.0          0.0           756.5       69
#
#      mSA  zeroBalCode  fmacRateAvg  rateDiffAvg  rateDiffAvgPct  origYear  \
# 0  35620          0.0         5.13       -0.755       -0.147173      2009
# 1      0          1.0         5.13       -0.005       -0.000975      2009
# 2      0          1.0         5.13       -0.005       -0.000975      2009
# 3      0          0.0         5.13       -0.255       -0.049708      2009
# 4  12100          0.0         5.13       -0.505       -0.098441      2009
#
#    origMonth
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %% [markdown]
# # Coerce the column dtype (int in this case)

# %%
df = df.astype({'origLTV':'int','origCLTV':'int','numBorrowers':'int','origDebtIncRatio':'int',\
               'mortInsType':'int','loanAge':'int',\
               'avgCreditScore':'int','zeroBalCode':'int'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240948 entries, 0 to 240947
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   origChannel       240948 non-null  object
#  1   sellerName        240948 non-null  object
#  2   origIntRate       240948 non-null  float64
#  3   origUPB           240948 non-null  int64
#  4   origLoanTerm      240948 non-null  int64
#  5   origLTV           240948 non-null  int32
#  6   origCLTV          240948 non-null  int32
#  7   numBorrowers      240948 non-null  int32
#  8   origDebtIncRatio  240948 non-null  int32
#  9   loanPurp          240948 non-null  object
#  10  propState         240948 non-null  object
#  11  zipCode           240948 non-null  int64
#  12  pMIperct          240948 non-null  float64
#  13  mortInsType       240948 non-null  int32
#  14  avgCreditScore    240948 non-null  int32
#  15  loanAge           240948 non-null  int32
#  16  mSA               240948 non-null  int64
#  17  zeroBalCode       240948 non-null  int32
#  18  fmacRateAvg       240948 non-null  float64
#  19  rateDiffAvg       240948 non-null  float64
#  20  rateDiffAvgPct    240948 non-null  float64
#  21  origYear          240948 non-null  int64
#  22  origMonth         240948 non-null  int64
# dtypes: float64(5), int32(8), int64(6), object(4)
# memory usage: 34.9+ MB

# %% [markdown]
# <a id='MLReady'></a>

# %% [markdown]
# # Train Test Split to create holdout dataset outside of PyCaret

# %%
good = df.zeroBalCode.value_counts()[0]
bad = df.zeroBalCode.value_counts()[1]
perct_bad = round(bad/(good + bad)*100,2)
print(f'We have {perct_bad}% Foreclosures in our dataset')
# Out:
# We have 8.96% Foreclosures in our dataset

# %%
from sklearn.model_selection import train_test_split

training_features, test_features, \
training_target, test_target, = train_test_split(
    df.drop(['zeroBalCode'], axis=1)
    , df['zeroBalCode']
    , test_size = .1
    , random_state=12
)

# %%
# Further split the training data into training/test
x_train, x_val, y_train, y_val = train_test_split(
    training_features
    , training_target
    , test_size = .1
    ,random_state=12
)

# %%
# For the training data, randomly sample 
# ros = RandomOverSampler(sampling_strategy='minority')
# x_train_res, y_train_res = ros.fit_sample(x_train, y_train)

# %%
print('#############################################')
print('Before oversampling: "Closed" crushes "Default" and causes issues:')
print(training_target.value_counts())
# print('')
# print('Before oversampling: "Closed" and "Default" are equal')
# print(y_train_res.value_counts())
# Out:
# #############################################
# Before oversampling: "Closed" crushes "Default" and causes issues:
# 0    197398
# 1     19455
# Name: zeroBalCode, dtype: int64

# %% [markdown]
# # Recombine X_train_res, y_train_res so PyCaret can deal with one df

# %%
y_train.shape
# Out:
# (195167,)

# %%
df = x_train.copy()

# %%
df['zeroBalCode'] = y_train

# %%
df.shape
# Out:
# (195167, 23)

# %% [markdown]
# # Review metrics last time before run (to have record of starting values)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195167 entries, 166485 to 166828
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   origChannel       195167 non-null  object
#  1   sellerName        195167 non-null  object
#  2   origIntRate       195167 non-null  float64
#  3   origUPB           195167 non-null  int64
#  4   origLoanTerm      195167 non-null  int64
#  5   origLTV           195167 non-null  int32
#  6   origCLTV          195167 non-null  int32
#  7   numBorrowers      195167 non-null  int32
#  8   origDebtIncRatio  195167 non-null  int32
#  9   loanPurp          195167 non-null  object
#  10  propState         195167 non-null  object
#  11  zipCode           195167 non-null  int64
#  12  pMIperct          195167 non-null  float64
#  13  mortInsType       195167 non-null  int32
#  14  avgCreditScore    195167 non-null  int32
#  15  loanAge           195167 non-null  int32
#  16  mSA               195167 non-null  int64
#  17  fmacRateAvg       195167 non-null  float64
#  18  rateDiffAvg       195167 non-null  float64
#  19  rateDiffAvgPct    195167 non-null  float64
#  20  origYear          195167 non-null  int64
#  21  origMonth         195167 non-null  int64
#  22  zeroBalCode       195167 non-null  int32
# dtypes: float64(5), int32(8), int64(6), object(4)
# memory usage: 29.8+ MB

# %%
df.head()
# Out:
#        origChannel                                 sellerName  origIntRate  \
# 166485           B                                      OTHER        4.250
# 121042           R                     WELLS FARGO BANK, N.A.        4.625
# 139151           C  JPMORGAN CHASE BANK, NATIONAL ASSOCIATION        4.375
# 86969            C                         GMAC MORTGAGE, LLC        4.375
# 22472            R                     WELLS FARGO BANK, N.A.        4.250
#
#         origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  \
# 166485   178000           360       54        54             1
# 121042    92000           180       80        80             1
# 139151   163000           240       54        87             2
# 86969    180000           360       80        80             1
# 22472     53000           180       36        36             2
#
#         origDebtIncRatio loanPurp propState  zipCode  pMIperct  mortInsType  \
# 166485                50        C        MA       27       0.0            0
# 121042                38        C        SC      298       0.0            0
# 139151                32        R        CA      917       0.0            0
# 86969                 36        P        CA      946       0.0            0
# 22472                 37        R        NC      272       0.0            0
#
#         avgCreditScore  loanAge    mSA  fmacRateAvg  rateDiffAvg  \
# 166485             712       84  39300       4.1060       0.1440
# 121042             763       55  12260       4.5640       0.0610
# 139151             676       42  31080       4.3000       0.0750
# 86969              777       81  41860       4.9300      -0.5550
# 22472              810       44  24660       5.0025      -0.7525
#
#         rateDiffAvgPct  origYear  origMonth  zeroBalCode
# 166485        0.035071      2011          9            0
# 121042        0.013365      2010          7            0
# 139151        0.017442      2010         11            0
# 86969        -0.112576      2009         12            0
# 22472        -0.150425      2009          3            0

# %% [markdown]
# # Pycaret - Setup with categorical definition

# %% [markdown]
# ### Use complex setup

# %%
model_setup = setup(
    df
    , target = 'zeroBalCode' # PyCaret will list this as "Label"
    , normalize = True
    , transformation = False
    , pca = False 
    , ignore_low_variance = False # Variance is calculated using the ratio of unique values to the number of samples, and the ratio of the most common value to the frequency of the second most common value. 
    , ignore_features = None
    , handle_unknown_categorical = True
    , remove_outliers = True
    , remove_multicollinearity = False
    , polynomial_features = False
    , trigonometry_features = False
    , feature_selection = False
    , feature_interaction = False
    , fix_imbalance = False
    , silent = True
    , profile = False
    # outliers from the training data are removed using PCA linear dimensionality reduction using the Singular Value Decomposition technique.
    , bin_numeric_features = [
        'avgCreditScore'
        ] # Set to True to bin numerics using K Means
    , categorical_features = [
         'origChannel'
        , 'loanPurp'
        , 'origYear'
        , 'origMonth'
        , 'mortInsType'
        , 'origLoanTerm'
        ]
    , high_cardinality_features = [
         'propState'
        , 'sellerName'
        , 'mSA'
        , 'zipCode'
    ]
    , high_cardinality_method = 'clustering'
    , numeric_features = [
        'origIntRate'
        , 'numBorrowers'
        , 'origUPB'
        , 'origLTV'
        , 'origCLTV'
        , 'pMIperct'
        , 'loanAge'
        , 'origDebtIncRatio'
        , 'avgCreditScore'
        , 'rateDiffAvg'
        , 'rateDiffAvgPct'
        , 'fmacRateAvg'
    ]
)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# #T_017700c0_fc41_11ea_9bf0_309c234564f5row8_col1,#T_017700c0_fc41_11ea_9bf0_309c234564f5row15_col1,#T_017700c0_fc41_11ea_9bf0_309c234564f5row25_col1,#T_017700c0_fc41_11ea_9bf0_309c234564f5row26_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_017700c0_fc41_11ea_9bf0_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_017700c0_fc41_11ea_9bf0_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_017700c0_fc41_11ea_9bf0_309c234564f5row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T
#             background-color:  yellow;
#             text-align:  left;
#         }#T_038673da_fc43_11ea_951b_309c234564f5row0_col8,#T_038673da_fc43_11ea_951b_309c234564f5row1_col8,#T_038673da_fc43_11ea_951b_309c234564f5row2_col8,#T_038673da_fc43_11ea_951b_309c234564f5row3_col8,#T_038673da_fc43_11ea_951b_309c234564f5row4_col8,#T_038673da_fc43_11ea_951b_309c234564f5row5_col8,#T_038673da_fc43_11ea_951b_309c234564f5row6_col8,#T_038673da_fc43_11ea_951b_309c234564f5row7_col8,#T_038673da_fc43_11ea_951b_309c234564f5row8_col8,#T_038673da_fc43_11ea_951b_309c234564f5row9_col8,#T_038673da_fc43_11ea_951b_309c234564f5row10_col8,#T_038673da_fc43_11ea_951b_309c234564f5row11_col8,#T_038673da_fc43_11ea_951b_309c234564f5row12_col8,#T_038673da_fc43_11ea_951b_309c234564f5row13_col8,#T_038673da_fc43_11ea_951b_309c234564f5row14_col8{
#             background-color:  lightgrey;
#             text-align:  left;
#         }</style><table id="T_038673da_fc43_11ea_951b_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_038673da_fc43_11ea_951b_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_038673da_fc43_11ea_951b_309c234564f5row0_col0" class="data row0 col0" >Naive Bayes</td>
#                         <td id="T_038673da_fc43_11ea_951b_309c234564f5row0_col1" class="data row0 col1" >0.7140</td>
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ## Create models

# %% [markdown]
# ### NB Classifier

# %%
nb = create_model('nb', fold=10)
# Out:
# <style  type="text/css" >
# #T_09c1cc94_fc43_11ea_acdd_309c234564f5row10_col0,#T_09c1cc94_fc43_11ea_acdd_309c234564f5row10_col1,#T_09c1cc94_fc43_11ea_acdd_309c234564f5row10_col2,#T_09c1cc94_fc43_11ea_acdd_309c234564f5row10_col3,#T_09c1cc94_fc43_11ea_acdd_309c234564f5row10_col4,#T_09c1cc94_fc43_11ea_acdd_309c234564f5row10_col5,#T_09c1cc94_fc43_11ea_acdd_309c234564f5row10_col6{
#             background:  yellow;
#         }</style><table id="T_09c1cc94_fc43_11ea_acdd_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09c1cc94_fc43_11ea_acdd_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row0_col0" class="data row0 col0" >0.7112</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row0_col1" class="data row0 col1" >0.7335</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row0_col2" class="data row0 col2" >0.5908</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row0_col3" class="data row0 col3" >0.1711</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row0_col4" class="data row0 col4" >0.2654</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row0_col5" class="data row0 col5" >0.1488</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row0_col6" class="data row0 col6" >0.1933</td>
#             </tr>
#             <tr>
#                         <th id="T_09c1cc94_fc43_11ea_acdd_309c234564f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row1_col0" class="data row1 col0" >0.7091</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row1_col1" class="data row1 col1" >0.7236</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row1_col2" class="data row1 col2" >0.5742</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row1_col3" class="data row1 col3" >0.1668</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row1_col4" class="data row1 col4" >0.2584</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row1_col5" class="data row1 col5" >0.1409</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row1_col6" class="data row1 col6" >0.1828</td>
#             </tr>
#             <tr>
#                         <th id="T_09c1cc94_fc43_11ea_acdd_309c234564f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row2_col0" class="data row2 col0" >0.7133</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row2_col1" class="data row2 col1" >0.7357</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row2_col2" class="data row2 col2" >0.5977</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row2_col3" class="data row2 col3" >0.1736</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row2_col4" class="data row2 col4" >0.2691</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row2_col5" class="data row2 col5" >0.1532</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row2_col6" class="data row2 col6" >0.1988</td>
#             </tr>
#             <tr>
#                         <th id="T_09c1cc94_fc43_11ea_acdd_309c234564f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row3_col0" class="data row3 col0" >0.7152</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row3_col1" class="data row3 col1" >0.7345</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row3_col2" class="data row3 col2" >0.6112</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row3_col3" class="data row3 col3" >0.1774</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row3_col4" class="data row3 col4" >0.2750</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row3_col5" class="data row3 col5" >0.1599</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row3_col6" class="data row3 col6" >0.2075</td>
#             </tr>
#             <tr>
#                         <th id="T_09c1cc94_fc43_11ea_acdd_309c234564f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row4_col0" class="data row4 col0" >0.7171</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row4_col1" class="data row4 col1" >0.7493</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row4_col2" class="data row4 col2" >0.6234</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row4_col3" class="data row4 col3" >0.1808</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row4_col4" class="data row4 col4" >0.2803</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row4_col5" class="data row4 col5" >0.1660</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row4_col6" class="data row4 col6" >0.2155</td>
#             </tr>
#             <tr>
#                         <th id="T_09c1cc94_fc43_11ea_acdd_309c234564f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row5_col0" class="data row5 col0" >0.7138</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row5_col1" class="data row5 col1" >0.7380</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row5_col2" class="data row5 col2" >0.6065</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row5_col3" class="data row5 col3" >0.1756</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row5_col4" class="data row5 col4" >0.2723</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row5_col5" class="data row5 col5" >0.1569</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row5_col6" class="data row5 col6" >0.2038</td>
#             </tr>
#             <tr>
#                         <th id="T_09c1cc94_fc43_11ea_acdd_309c234564f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row6_col0" class="data row6 col0" >0.7187</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row6_col1" class="data row6 col1" >0.7388</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row6_col2" class="data row6 col2" >0.6065</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row6_col3" class="data row6 col3" >0.1784</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row6_col4" class="data row6 col4" >0.2757</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row6_col5" class="data row6 col5" >0.1613</td>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row6_col6" class="data row6 col6" >0.2080</td>
#             </tr>
#             <tr>
#                         <th id="T_09c1cc94_fc43_11ea_acdd_309c234564f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_09c1cc94_fc43_11ea_acdd_309c234564f5row7_co

# %% [markdown]
# ## Evaluate Models

# %%
evaluate_model(nb)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ## Tune Model

# %%
tuned_nb = tune_model(nb, optimize = 'Recall')
# Out:
# <style  type="text/css" >
# #T_1d0643ec_fc43_11ea_961c_309c234564f5row10_col0,#T_1d0643ec_fc43_11ea_961c_309c234564f5row10_col1,#T_1d0643ec_fc43_11ea_961c_309c234564f5row10_col2,#T_1d0643ec_fc43_11ea_961c_309c234564f5row10_col3,#T_1d0643ec_fc43_11ea_961c_309c234564f5row10_col4,#T_1d0643ec_fc43_11ea_961c_309c234564f5row10_col5,#T_1d0643ec_fc43_11ea_961c_309c234564f5row10_col6{
#             background:  yellow;
#         }</style><table id="T_1d0643ec_fc43_11ea_961c_309c234564f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1d0643ec_fc43_11ea_961c_309c234564f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row0_col0" class="data row0 col0" >0.7112</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row0_col1" class="data row0 col1" >0.7335</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row0_col2" class="data row0 col2" >0.5908</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row0_col3" class="data row0 col3" >0.1711</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row0_col4" class="data row0 col4" >0.2654</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row0_col5" class="data row0 col5" >0.1488</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row0_col6" class="data row0 col6" >0.1933</td>
#             </tr>
#             <tr>
#                         <th id="T_1d0643ec_fc43_11ea_961c_309c234564f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row1_col0" class="data row1 col0" >0.7091</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row1_col1" class="data row1 col1" >0.7236</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row1_col2" class="data row1 col2" >0.5742</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row1_col3" class="data row1 col3" >0.1668</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row1_col4" class="data row1 col4" >0.2584</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row1_col5" class="data row1 col5" >0.1409</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row1_col6" class="data row1 col6" >0.1828</td>
#             </tr>
#             <tr>
#                         <th id="T_1d0643ec_fc43_11ea_961c_309c234564f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row2_col0" class="data row2 col0" >0.7133</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row2_col1" class="data row2 col1" >0.7357</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row2_col2" class="data row2 col2" >0.5977</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row2_col3" class="data row2 col3" >0.1736</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row2_col4" class="data row2 col4" >0.2691</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row2_col5" class="data row2 col5" >0.1532</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row2_col6" class="data row2 col6" >0.1988</td>
#             </tr>
#             <tr>
#                         <th id="T_1d0643ec_fc43_11ea_961c_309c234564f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row3_col0" class="data row3 col0" >0.7152</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row3_col1" class="data row3 col1" >0.7345</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row3_col2" class="data row3 col2" >0.6112</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row3_col3" class="data row3 col3" >0.1774</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row3_col4" class="data row3 col4" >0.2750</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row3_col5" class="data row3 col5" >0.1599</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row3_col6" class="data row3 col6" >0.2075</td>
#             </tr>
#             <tr>
#                         <th id="T_1d0643ec_fc43_11ea_961c_309c234564f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row4_col0" class="data row4 col0" >0.7171</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row4_col1" class="data row4 col1" >0.7493</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row4_col2" class="data row4 col2" >0.6234</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row4_col3" class="data row4 col3" >0.1808</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row4_col4" class="data row4 col4" >0.2803</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row4_col5" class="data row4 col5" >0.1660</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row4_col6" class="data row4 col6" >0.2155</td>
#             </tr>
#             <tr>
#                         <th id="T_1d0643ec_fc43_11ea_961c_309c234564f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row5_col0" class="data row5 col0" >0.7138</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row5_col1" class="data row5 col1" >0.7380</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row5_col2" class="data row5 col2" >0.6065</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row5_col3" class="data row5 col3" >0.1756</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row5_col4" class="data row5 col4" >0.2723</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row5_col5" class="data row5 col5" >0.1569</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row5_col6" class="data row5 col6" >0.2038</td>
#             </tr>
#             <tr>
#                         <th id="T_1d0643ec_fc43_11ea_961c_309c234564f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row6_col0" class="data row6 col0" >0.7187</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row6_col1" class="data row6 col1" >0.7388</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row6_col2" class="data row6 col2" >0.6065</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row6_col3" class="data row6 col3" >0.1784</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row6_col4" class="data row6 col4" >0.2757</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row6_col5" class="data row6 col5" >0.1613</td>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row6_col6" class="data row6 col6" >0.2080</td>
#             </tr>
#             <tr>
#                         <th id="T_1d0643ec_fc43_11ea_961c_309c234564f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_1d0643ec_fc43_11ea_961c_309c234564f5row7_co

# %%
evaluate_model(tuned_nb)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
final_nb = finalize_model(tuned_nb)

# %%
evaluate_model(final_nb)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# # Predict models

# %%
predicted_final_nb = predict_model(final_nb)
# Out:
#          Model  Accuracy     AUC  Recall   Prec.      F1  Kappa     MCC
# 0  Naive Bayes    0.7148  0.7383  0.6126  0.1773  0.2751   0.16  0.2079

# %%
predicted_nb = predict_model(nb)
# Out:
#          Model  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Naive Bayes    0.7144  0.7378  0.6142  0.1774  0.2752  0.1602  0.2083

# %%
predicted_nb_tuned = predict_model(tuned_nb)
# Out:
#          Model  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Naive Bayes    0.7144  0.7378  0.6142  0.1774  0.2752  0.1602  0.2083

# %% [markdown]
# # The golden moment... put 10% sample test data through the models...

# %% [markdown]
# # Recombine test_features, test_target at first train/test/split
#  This "test" set was split BEFORE Oversampling. PyCaret takes the "train" from this split and splits it internally again. Since we have no control of how PyCaret does this we needed to do a train/test split before we input the training set into PyCaret. Now we will recombine the test_features and test_target into one new df

# %%
test_features.shape
# Out:
# (24095, 22)

# %%
test_target.shape
# Out:
# (24095,)

# %%
test_df = test_features.copy()

# %%
test_df['zeroBalCode'] = test_target

# %%
test_df.shape
# Out:
# (24095, 23)

# %%
totalTestCount = test_df.zeroBalCode.value_counts().sum()
posTestCount = test_df.zeroBalCode.value_counts()[1]
print('#############################################')
print('This "Test" set has not been oversamplied')
print(test_df.zeroBalCode.value_counts())
print(f'Positive samples are {round(posTestCount/totalTestCount*100,2)}%')
# Out:
# #############################################
# This "Test" set has not been oversamplied
# 0    21971
# 1     2124
# Name: zeroBalCode, dtype: int64
# Positive samples are 8.82%

# %% [markdown]
# ## Create Confusion Matrix output functions

# %%
def calc_confusion(row):
    if ((row['zeroBalCode'] == 0) & (row['Label'] == 0)):
        value = 'TrueNegative'
    elif ((row['zeroBalCode'] == 0) & (row['Label'] == 1)):
        value = 'FalsePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 1)):
        value = 'TruePositive'
    elif ((row['zeroBalCode'] == 1) & (row['Label'] == 0)):
        value = 'FalseNegative'
    else:
        value = 'Undefined'
    return value

# %%
def cM(df):
    print(f'           ##############################')
    print(f'           #             #              #')
    print(f'         0 #    {df["TrueNegative"]}     #     {df["FalsePositive"]}      #')
    print(f'  True     #             #              #')
    print(f'  Class    ##############################')
    print(f'           #             #              #')
    print(f'         1 #    {df["FalseNegative"]}      #     {df["TruePositive"]}      #')
    print(f'           #             #              #')
    print(f'           ##############################')
    print(f'                  0              1        ')
    print(f'                  Predicted Class           ')

# %%
def cMCalc():
    # 0 or 2 = Predict equals truth, 1 = Predict doesn't equal truth
    totalNegative = confusionMatrix['TrueNegative'] + confusionMatrix['FalseNegative']
    totalPositive = confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']
    total = totalNegative + totalPositive
    trueNegativePct = confusionMatrix['TrueNegative'] / total * 100
    falseNegativePct = confusionMatrix['FalseNegative'] / total * 100
    truePositivePct = confusionMatrix['TruePositive'] / total * 100
    falsePositivePct = confusionMatrix['FalsePositive'] / total * 100

    # Accuracy Calculation
    accuracy = (confusionMatrix['TruePositive'] + confusionMatrix['TrueNegative'])/(totalPositive + totalNegative)
    # Recall Calculation
    recall = (confusionMatrix['TruePositive']/(confusionMatrix['TruePositive'] + confusionMatrix['FalseNegative']))
    # Precision Calculation
    precision = (confusionMatrix['TruePositive']/(confusionMatrix['TruePositive'] + confusionMatrix['FalsePositive']))

    print(f'TrueNegative:  {round(trueNegativePct,2)}%')
    print(f'FalseNegative:  {round(falseNegativePct,2)}%')
    print(f'TruePositive:   {round(truePositivePct,2)}%')
    print(f'FalsePositive: {round(falsePositivePct,2)}%')
    print(f'#####################################################')
    print(f'Accuracy: {round(accuracy,2)*100}%   Recall: {round(recall,2)*100}%   Precision: {round(precision,2)*100}%')
    print(f'#####################################################')

# %% [markdown]
# # Evaluate Models

# %%
predictions = predict_model(final_nb, data=test_df)

# %%
pd.set_option('max_columns',None)
predictions.head()
# Out:
#   origChannel                                 sellerName  origIntRate  \
# 0           R                     WELLS FARGO BANK, N.A.        4.750
# 1           C                      BANK OF AMERICA, N.A.        4.875
# 2           R  JPMORGAN CHASE BANK, NATIONAL ASSOCIATION        4.875
# 3           R                   PHH MORTGAGE CORPORATION        3.750
# 4           R                                      OTHER        4.000
#
#    origUPB  origLoanTerm  origLTV  origCLTV  numBorrowers  origDebtIncRatio  \
# 0   248000           360       90        90             1                44
# 1   289000           360       89        89             2                40
# 2   230000           360       80        80             2                41
# 3   140000           180       80        80             1                22
# 4   220000           360       80        80             2                39
#
#   loanPurp propState  zipCode  pMIperct  mortInsType  avgCreditScore  loanAge  \
# 0        R        MD      210      25.0            1             703       72
# 1        R        RI       28      25.0            1             776       70
# 2        C        NJ       77       0.0            0             784       68
# 3        C        TN      373       0.0            0             670       71
# 4        C        MI      491       0.0            0             745       83
#
#      mSA  fmacRateAvg  rateDiffAvg  rateDiffAvgPct  origYear  origMonth  \
# 0  12580       4.8575      -0.1075       -0.022131      2009          5
# 1  39300       4.8575       0.0175        0.003603      2009          5
# 2  35620       4.8575       0.0175        0.003603      2009          5
# 3      0       3.6750       0.0750        0.020408      2012          6
# 4  35660       3.6020       0.3980        0.110494      2012          8
#
#    zeroBalCode  Label   Score
# 0            0      1  0.8417
# 1            0      0  0.1697
# 2            0      0  0.0010
# 3            0      1  0.6661
# 4            1      1  0.7747

# %%
results = predictions[['zeroBalCode','Label','Score']]

# %%
predictions.Label.value_counts()
# Out:
# 0    18273
# 1     5822
# Name: Label, dtype: int64

# %%
results['Confusion'] = results.apply(calc_confusion, axis=1)

# %%
confusionMatrix = results.Confusion.value_counts().to_dict()

# %%
cM(confusionMatrix)
# Out:
#            ##############################
#            #             #              #
#          0 #    17202     #     4769      #
#   True     #             #              #
#   Class    ##############################
#            #             #              #
#          1 #    1071      #     1053      #
#            #             #              #
#            ##############################
#                   0              1
#                   Predicted Class

# %%
cMCalc()
# Out:
# TrueNegative:  71.39%
# FalseNegative:  4.44%
# TruePositive:   4.37%
# FalsePositive: 19.79%
# #####################################################
# Accuracy: 76.0%   Recall: 50.0%   Precision: 18.0%
# #####################################################

# %%
#save_model(final_nb, 'np.final5pct_092020')
