# %% [markdown]
# ## Import Dependencies

# %%
import csv
from pathlib import Path
import pandas as pd
import glob
from datetime import datetime, timedelta
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Prepare the Processed Acquisition file

# %%
acq_df = pd.read_csv('data/FMAcqProcessed2.csv')

# %%
acq_df.head()
# Out:
#    Unnamed: 0  loanIdentifier origChannel               sellerName  \
# 0         711    102575552799           R                    OTHER
# 1         752    102718910405           R  JPMORGAN CHASE BANK, NA
# 2         785    102891952623           R  JPMORGAN CHASE BANK, NA
# 3         841    103123692845           B  JPMORGAN CHASE BANK, NA
# 4        1526    105732468779           C             REGIONS BANK
#
#    origIntRate  origUPB  origLoanTerm    origDate firstPmtDate  origLTV  \
# 0        7.625   253000           360  2000-02-01   2000-04-01     79.0
# 1        8.500   187000           360  2000-02-01   2000-04-01     80.0
# 2        8.625   150000           360  2000-01-01   2000-03-01     80.0
# 3        8.500   243000           360  2000-02-01   2000-04-01     80.0
# 4        8.250   103000           360  2000-02-01   2000-04-01     80.0
#
#    origCLTV  numBorrowers  origDebtIncRatio loanPurp propState  zipCode  \
# 0      95.0           2.0              21.0        R        IN      468
# 1      90.0           2.0              31.0        P        MI      483
# 2      95.0           1.0              37.0        P        MA       21
# 3      95.0           1.0              49.0        P        CA      926
# 4      90.0           2.0              20.0        P        TX      781
#
#    pMIperct  mortInsType  bestCreditScore  worstCreditScore  avgCreditScore
# 0       0.0          0.0            656.0             655.0           655.5
# 1       0.0          0.0            712.0             706.0           709.0
# 2       0.0          0.0            717.0             717.0           717.0
# 3       0.0          0.0            682.0             682.0           682.0
# 4       0.0          0.0            747.0             694.0           720.5

# %%
#Dropping columns we don't want
acq_df.drop(['Unnamed: 0'],1,inplace=True)

# %%
acq_df['origDate'] = pd.to_datetime(acq_df['origDate'], format='%Y/%m/%d')
acq_df['firstPmtDate'] = pd.to_datetime(acq_df['firstPmtDate'], format='%Y/%m/%d')

# %%
acq_df = acq_df.rename(columns={'loanIdentifier':'id'})

# %%
acq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25993874 entries, 0 to 25993873
# Data columns (total 20 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   id                int64
#  1   origChannel       object
#  2   sellerName        object
#  3   origIntRate       float64
#  4   origUPB           int64
#  5   origLoanTerm      int64
#  6   origDate          datetime64[ns]
#  7   firstPmtDate      datetime64[ns]
#  8   origLTV           float64
#  9   origCLTV          float64
#  10  numBorrowers      float64
#  11  origDebtIncRatio  float64
#  12  loanPurp          object
#  13  propState         object
#  14  zipCode           int64
#  15  pMIperct          float64
#  16  mortInsType       float64
#  17  bestCreditScore   float64
#  18  worstCreditScore  float64
#  19  avgCreditScore    float64
# dtypes: datetime64[ns](2), float64(10), int64(4), object(4)
# memory usage: 3.9+ GB

# %%
acq_df.head()
# Out:
#              id origChannel               sellerName  origIntRate  origUPB  \
# 0  102575552799           R                    OTHER        7.625   253000
# 1  102718910405           R  JPMORGAN CHASE BANK, NA        8.500   187000
# 2  102891952623           R  JPMORGAN CHASE BANK, NA        8.625   150000
# 3  103123692845           B  JPMORGAN CHASE BANK, NA        8.500   243000
# 4  105732468779           C             REGIONS BANK        8.250   103000
#
#    origLoanTerm   origDate firstPmtDate  origLTV  origCLTV  numBorrowers  \
# 0           360 2000-02-01   2000-04-01     79.0      95.0           2.0
# 1           360 2000-02-01   2000-04-01     80.0      90.0           2.0
# 2           360 2000-01-01   2000-03-01     80.0      95.0           1.0
# 3           360 2000-02-01   2000-04-01     80.0      95.0           1.0
# 4           360 2000-02-01   2000-04-01     80.0      90.0           2.0
#
#    origDebtIncRatio loanPurp propState  zipCode  pMIperct  mortInsType  \
# 0              21.0        R        IN      468       0.0          0.0
# 1              31.0        P        MI      483       0.0          0.0
# 2              37.0        P        MA       21       0.0          0.0
# 3              49.0        P        CA      926       0.0          0.0
# 4              20.0        P        TX      781       0.0          0.0
#
#    bestCreditScore  worstCreditScore  avgCreditScore
# 0            656.0             655.0           655.5
# 1            712.0             706.0           709.0
# 2            717.0             717.0           717.0
# 3            682.0             682.0           682.0
# 4            747.0             694.0           720.5

# %%
acq_df.shape
# Out:
# (25993874, 20)

# %% [markdown]
# # Prepare the Processed Performance file

# %%
perf_df = pd.read_csv('D:\FMPerfProcessed.csv')

# %%
perf_df['rptPeriod'] = pd.to_datetime(perf_df['rptPeriod'], format='%Y/%m/%d')
perf_df['lastPdInstDate'] = pd.to_datetime(perf_df['lastPdInstDate'], format='%Y/%m/%d')
perf_df['zeroBalDate'] = pd.to_datetime(perf_df['zeroBalDate'], format='%Y/%m/%d')
perf_df['forecloDate'] = pd.to_datetime(perf_df['forecloDate'], format='%Y/%m/%d')
perf_df['dispDate'] = pd.to_datetime(perf_df['dispDate'], format='%Y/%m/%d')

# %%
perf_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4052974 entries, 0 to 4052973
# Data columns (total 29 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   id                          int64
#  1   rptPeriod                   datetime64[ns]
#  2   currIntRate                 float64
#  3   currUPB                     float64
#  4   loanAge                     int64
#  5   monMatur                    float64
#  6   mSA                         int64
#  7   zeroBalCode                 float64
#  8   zeroBalDate                 datetime64[ns]
#  9   lastPdInstDate              datetime64[ns]
#  10  forecloDate                 datetime64[ns]
#  11  dispDate                    datetime64[ns]
#  12  forecloCost                 float64
#  13  propRepCost                 float64
#  14  recovCosts                  float64
#  15  miscCost                    float64
#  16  holdTaxCost                 float64
#  17  saleProceed                 float64
#  18  credEnhProceed              float64
#  19  repurchProceed              float64
#  20  otherForecloProceed         float64
#  21  nonIntUPB                   float64
#  22  prinForgivBal               float64
#  23  repurchMakeWholeProceedFlg  int64
#  24  forecloPrinWriteOffAmnt     float64
#  25  servActivIndicator          float64
#  26  deliqGood                   int64
#  27  deliqBad                    int64
#  28  deliqMax                    float64
# dtypes: datetime64[ns](5), float64(18), int64(6)
# memory usage: 896.7 MB

# %% [markdown]
# ## Get Freddie Mac 30 yr weekly rate

# %%
# import training_data via pandas module
fmac30 = pd.read_csv("data/FMAC30Agg.csv", low_memory=False)

# %%
fmac30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590 entries, 0 to 589
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   month_year          590 non-null    object
#  1   fmacRateMax         590 non-null    float64
#  2   fmacRateMin         590 non-null    float64
#  3   fmacRateAvg         590 non-null    float64
#  4   fmacRateVolatility  590 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 23.2+ KB

# %%
fmac30['month_year'] = pd.to_datetime(fmac30['month_year'])

# %%
fmac30 = fmac30.rename(columns={'month_year':'origDate'})

# %%
fmac30 = fmac30.set_index('origDate')

# %%
fmac30.head()
# Out:
#             fmacRateMax  fmacRateMin  fmacRateAvg  fmacRateVolatility
# origDate
# 1971-04-01         7.33         7.29       7.3100            0.005487
# 1971-05-01         7.46         7.38       7.4250            0.010840
# 1971-06-01         7.54         7.52       7.5300            0.002660
# 1971-07-01         7.69         7.54       7.6040            0.019894
# 1971-08-01         7.73         7.66       7.6975            0.009138

# %% [markdown]
# ## Get 10 yr Treasury daily rate

# %%
# import training_data via pandas module
fred10 = pd.read_csv("download/FRED-DGS10.csv", low_memory=False)

# %%
fred10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14575 entries, 0 to 14574
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    14575 non-null  object
#  1   Value   14575 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 227.9+ KB

# %%
fred10['Date'] = pd.to_datetime(fred10['Date'])

# %%
fred10 = fred10.set_index('Date').resample('D').ffill().reset_index()

# %%
fred10 = fred10.rename(columns={'Date':'origDate','Value':'fredRate'})

# %% [markdown]
# ## Merge data

# %%
acq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25993874 entries, 0 to 25993873
# Data columns (total 20 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   id                int64
#  1   origChannel       object
#  2   sellerName        object
#  3   origIntRate       float64
#  4   origUPB           int64
#  5   origLoanTerm      int64
#  6   origDate          datetime64[ns]
#  7   firstPmtDate      datetime64[ns]
#  8   origLTV           float64
#  9   origCLTV          float64
#  10  numBorrowers      float64
#  11  origDebtIncRatio  float64
#  12  loanPurp          object
#  13  propState         object
#  14  zipCode           int64
#  15  pMIperct          float64
#  16  mortInsType       float64
#  17  bestCreditScore   float64
#  18  worstCreditScore  float64
#  19  avgCreditScore    float64
# dtypes: datetime64[ns](2), float64(10), int64(4), object(4)
# memory usage: 3.9+ GB

# %%
perf_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4052974 entries, 0 to 4052973
# Data columns (total 29 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   id                          int64
#  1   rptPeriod                   datetime64[ns]
#  2   currIntRate                 float64
#  3   currUPB                     float64
#  4   loanAge                     int64
#  5   monMatur                    float64
#  6   mSA                         int64
#  7   zeroBalCode                 float64
#  8   zeroBalDate                 datetime64[ns]
#  9   lastPdInstDate              datetime64[ns]
#  10  forecloDate                 datetime64[ns]
#  11  dispDate                    datetime64[ns]
#  12  forecloCost                 float64
#  13  propRepCost                 float64
#  14  recovCosts                  float64
#  15  miscCost                    float64
#  16  holdTaxCost                 float64
#  17  saleProceed                 float64
#  18  credEnhProceed              float64
#  19  repurchProceed              float64
#  20  otherForecloProceed         float64
#  21  nonIntUPB                   float64
#  22  prinForgivBal               float64
#  23  repurchMakeWholeProceedFlg  int64
#  24  forecloPrinWriteOffAmnt     float64
#  25  servActivIndicator          float64
#  26  deliqGood                   int64
#  27  deliqBad                    int64
#  28  deliqMax                    float64
# dtypes: datetime64[ns](5), float64(18), int64(6)
# memory usage: 896.7 MB

# %%
# Merge data
merged = pd.merge(acq_df, perf_df, on=["id"], how='inner')
merged.shape
# Out:
# (2663264, 48)

# %%
# Merge data
merged = pd.merge(merged, fmac30, on=["origDate"])
merged.shape
# Out:
# (2663264, 52)

# %%
# Merge data
merged = pd.merge(merged, fred10, on=["origDate"])
merged.shape
# Out:
# (2663264, 53)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2663264 entries, 0 to 2663263
# Data columns (total 53 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   id                          int64
#  1   origChannel                 object
#  2   sellerName                  object
#  3   origIntRate                 float64
#  4   origUPB                     int64
#  5   origLoanTerm                int64
#  6   origDate                    datetime64[ns]
#  7   firstPmtDate                datetime64[ns]
#  8   origLTV                     float64
#  9   origCLTV                    float64
#  10  numBorrowers                float64
#  11  origDebtIncRatio            float64
#  12  loanPurp                    object
#  13  propState                   object
#  14  zipCode                     int64
#  15  pMIperct                    float64
#  16  mortInsType                 float64
#  17  bestCreditScore             float64
#  18  worstCreditScore            float64
#  19  avgCreditScore              float64
#  20  rptPeriod                   datetime64[ns]
#  21  currIntRate                 float64
#  22  currUPB                     float64
#  23  loanAge                     int64
#  24  monMatur                    float64
#  25  mSA                         int64
#  26  zeroBalCode                 float64
#  27  zeroBalDate                 datetime64[ns]
#  28  lastPdInstDate              datetime64[ns]
#  29  forecloDate                 datetime64[ns]
#  30  dispDate                    datetime64[ns]
#  31  forecloCost                 float64
#  32  propRepCost                 float64
#  33  recovCosts                  float64
#  34  miscCost                    float64
#  35  holdTaxCost                 float64
#  36  saleProceed                 float64
#  37  credEnhProceed              float64
#  38  repurchProceed              float64
#  39  otherForecloProceed         float64
#  40  nonIntUPB                   float64
#  41  prinForgivBal               float64
#  42  repurchMakeWholeProceedFlg  int64
#  43  forecloPrinWriteOffAmnt     float64
#  44  servActivIndicator          float64
#  45  deliqGood                   int64
#  46  deliqBad                    int64
#  47  deliqMax                    float64
#  48  fmacRateMax                 float64
#  49  fmacRateMin                 float64
#  50  fmacRateAvg                 float64
#  51  fmacRateVolatility          float64
#  52  fredRate                    float64
# dtypes: datetime64[ns](7), float64(33), int64(9), object(4)
# memory usage: 1.1+ GB

# %%
fmac30.head()
# Out:
#             fmacRateMax  fmacRateMin  fmacRateAvg  fmacRateVolatility
# origDate
# 1971-04-01         7.33         7.29       7.3100            0.005487
# 1971-05-01         7.46         7.38       7.4250            0.010840
# 1971-06-01         7.54         7.52       7.5300            0.002660
# 1971-07-01         7.69         7.54       7.6040            0.019894
# 1971-08-01         7.73         7.66       7.6975            0.009138

# %%
merged['rateDiffAbove'] = merged['origIntRate'] - merged['fmacRateMax']

# %%
merged['rateDiffBelow'] = merged['fmacRateMin'] - merged['origIntRate']

# %%
merged['rateDiffAvg'] = merged['origIntRate'] - merged['fmacRateAvg']

# %%
merged['rateDiffAbovePct'] = merged['rateDiffAbove'] / merged['fmacRateMax']

# %%
merged['rateDiffBelowPct'] = merged['rateDiffBelow'] / merged['fmacRateMin']

# %%
merged['rateDiffAvgPct'] = merged['rateDiffAvg'] / merged['fmacRateAvg']

# %%
acq_df['id'].nunique()
# Out:
# 25993874

# %%
perf_df['id'].nunique()
# Out:
# 4052974

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2663264 entries, 0 to 2663263
# Data columns (total 59 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   id                          int64
#  1   origChannel                 object
#  2   sellerName                  object
#  3   origIntRate                 float64
#  4   origUPB                     int64
#  5   origLoanTerm                int64
#  6   origDate                    datetime64[ns]
#  7   firstPmtDate                datetime64[ns]
#  8   origLTV                     float64
#  9   origCLTV                    float64
#  10  numBorrowers                float64
#  11  origDebtIncRatio            float64
#  12  loanPurp                    object
#  13  propState                   object
#  14  zipCode                     int64
#  15  pMIperct                    float64
#  16  mortInsType                 float64
#  17  bestCreditScore             float64
#  18  worstCreditScore            float64
#  19  avgCreditScore              float64
#  20  rptPeriod                   datetime64[ns]
#  21  currIntRate                 float64
#  22  currUPB                     float64
#  23  loanAge                     int64
#  24  monMatur                    float64
#  25  mSA                         int64
#  26  zeroBalCode                 float64
#  27  zeroBalDate                 datetime64[ns]
#  28  lastPdInstDate              datetime64[ns]
#  29  forecloDate                 datetime64[ns]
#  30  dispDate                    datetime64[ns]
#  31  forecloCost                 float64
#  32  propRepCost                 float64
#  33  recovCosts                  float64
#  34  miscCost                    float64
#  35  holdTaxCost                 float64
#  36  saleProceed                 float64
#  37  credEnhProceed              float64
#  38  repurchProceed              float64
#  39  otherForecloProceed         float64
#  40  nonIntUPB                   float64
#  41  prinForgivBal               float64
#  42  repurchMakeWholeProceedFlg  int64
#  43  forecloPrinWriteOffAmnt     float64
#  44  servActivIndicator          float64
#  45  deliqGood                   int64
#  46  deliqBad                    int64
#  47  deliqMax                    float64
#  48  fmacRateMax                 float64
#  49  fmacRateMin                 float64
#  50  fmacRateAvg                 float64
#  51  fmacRateVolatility          float64
#  52  fredRate                    float64
#  53  rateDiffAbove               float64
#  54  rateDiffBelow               float64
#  55  rateDiffAvg                 float64
#  56  rateDiffAbovePct            float64
#  57  rateDiffBelowPct            float64
#  58  rateDiffAvgPct              float64
# dtypes: datetime64[ns](7), float64(39), int64(9), object(4)
# memory usage: 1.2+ GB

# %%
# Keep the loanAge,monMatur parameters in this join notebook variation
merged.drop(['firstPmtDate','rptPeriod','currIntRate','currUPB',\
         'zeroBalDate','lastPdInstDate','forecloDate','dispDate','forecloCost','propRepCost','recovCosts',\
         'miscCost','holdTaxCost','saleProceed','credEnhProceed','repurchProceed','otherForecloProceed',\
         'nonIntUPB','prinForgivBal','repurchMakeWholeProceedFlg','forecloPrinWriteOffAmnt',\
             'servActivIndicator'],1,inplace=True)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2663264 entries, 0 to 2663263
# Data columns (total 37 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   id                  int64
#  1   origChannel         object
#  2   sellerName          object
#  3   origIntRate         float64
#  4   origUPB             int64
#  5   origLoanTerm        int64
#  6   origDate            datetime64[ns]
#  7   origLTV             float64
#  8   origCLTV            float64
#  9   numBorrowers        float64
#  10  origDebtIncRatio    float64
#  11  loanPurp            object
#  12  propState           object
#  13  zipCode             int64
#  14  pMIperct            float64
#  15  mortInsType         float64
#  16  bestCreditScore     float64
#  17  worstCreditScore    float64
#  18  avgCreditScore      float64
#  19  loanAge             int64
#  20  monMatur            float64
#  21  mSA                 int64
#  22  zeroBalCode         float64
#  23  deliqGood           int64
#  24  deliqBad            int64
#  25  deliqMax            float64
#  26  fmacRateMax         float64
#  27  fmacRateMin         float64
#  28  fmacRateAvg         float64
#  29  fmacRateVolatility  float64
#  30  fredRate            float64
#  31  rateDiffAbove       float64
#  32  rateDiffBelow       float64
#  33  rateDiffAvg         float64
#  34  rateDiffAbovePct    float64
#  35  rateDiffBelowPct    float64
#  36  rateDiffAvgPct      float64
# dtypes: datetime64[ns](1), float64(24), int64(8), object(4)
# memory usage: 772.1+ MB

# %%
merged.apply(lambda x: x.isnull().sum(), axis=0)
# Out:
# id                       0
# origChannel              0
# sellerName               0
# origIntRate              0
# origUPB                  0
# origLoanTerm             0
# origDate                 0
# origLTV                  0
# origCLTV                 0
# numBorrowers             0
# origDebtIncRatio         0
# loanPurp                 0
# propState                0
# zipCode                  0
# pMIperct                 0
# mortInsType              0
# bestCreditScore          0
# worstCreditScore         0
# avgCreditScore           0
# loanAge                  0
# monMatur              1684
# mSA                      0
# zeroBalCode              0
# deliqGood                0
# deliqBad                 0
# deliqMax                 0
# fmacRateMax              0
# fmacRateMin              0
# fmacRateAvg              0
# fmacRateVolatility       0
# fredRate                 0
# rateDiffAbove            0
# rateDiffBelow            0
# rateDiffAvg              0
# rateDiffAbovePct         0
# rateDiffBelowPct         0
# rateDiffAvgPct           0
# dtype: int64

# %% [markdown]
# ## Write the all years to a *.csv file

# %%
merged.to_csv('data/FM_Acq2_Perf_FMAC2_loanAge.csv')

# %%
merged.head()
# Out:
#              id origChannel               sellerName  origIntRate  origUPB  \
# 0  102718910405           R  JPMORGAN CHASE BANK, NA        8.500   187000
# 1  103123692845           B  JPMORGAN CHASE BANK, NA        8.500   243000
# 2  117311391991           B  JPMORGAN CHASE BANK, NA        8.000   253000
# 3  135950664937           R  JPMORGAN CHASE BANK, NA        8.500   138000
# 4  226095365894           B  JPMORGAN CHASE BANK, NA        8.875   166000
#
#    origLoanTerm   origDate  origLTV  origCLTV  numBorrowers  origDebtIncRatio  \
# 0           360 2000-02-01     80.0      90.0           2.0              31.0
# 1           360 2000-02-01     80.0      95.0           1.0              49.0
# 2           360 2000-02-01     79.0      89.0           2.0              34.0
# 3           360 2000-02-01     80.0      95.0           1.0              30.0
# 4           360 2000-02-01     80.0      95.0           2.0              24.0
#
#   loanPurp propState  zipCode  pMIperct  mortInsType  bestCreditScore  \
# 0        P        MI      483       0.0          0.0            712.0
# 1        P        CA      926       0.0          0.0            682.0
# 2        P        CA      953       0.0          0.0            810.0
# 3        P        MA       17       0.0          0.0            718.0
# 4        P        MA       18       0.0          0.0            782.0
#
#    worstCreditScore  avgCreditScore  loanAge  monMatur    mSA  zeroBalCode  \
# 0             706.0           709.0       70     290.0  19820          1.0
# 1             682.0           682.0       21     339.0  31100          1.0
# 2             784.0           797.0       36     324.0  44700          1.0
# 3             718.0           718.0       16     344.0  14460          1.0
# 4             752.0           767.0       24     336.0  14460          1.0
#
#    deliqGood  deliqBad  deliqMax  fmacRateMax  fmacRateMin  fmacRateAvg  \
# 0         50        20       2.0         8.38         8.25        8.325
# 1         17         4       1.0         8.38         8.25        8.325
# 2         33         3       1.0         8.38         8.25        8.325
# 3         14         2       1.0         8.38         8.25        8.325
# 4         23         1       1.0         8.38         8.25        8.325
#
#    fmacRateVolatility  fredRate  rateDiffAbove  rateDiffBelow  rateDiffAvg  \
# 0            0.015758      6.62          0.120         -0.250        0.175
# 1            0.015758      6.62          0.120         -0.250        0.175
# 2            0.015758      6.62         -0.380          0.250       -0.325
# 3            0.015758      6.62          0.120         -0.250        0.175
# 4            0.015758      6.62          0.495         -0.625        0.550
#
#    rateDiffAbovePct  rateDiffBelowPct  rateDiffAvgPct
# 0          0.014320         -0.030303        0.021021
# 1          0.014320         -0.030303        0.021021
# 2         -0.045346          0.030303       -0.039039
# 3          0.014320         -0.030303        0.021021
# 4          0.059069         -0.075758        0.066066

# %%
df = merged.copy()

# %% [markdown]
# ## Cut the data so it is manageable into the "3 Epochs"
# * EPOCH 1 - APR 1999 - AUG 2008
# * EPOCH 2 - JAN 2009 - JUNE 2013
# * EPOCH 3 - SEPT 2013 - MARCH 2019

# %% [markdown]
# ### EPOCH 1

# %%
# EPOCH 1 - APR 1999 - AUG 2008
epoch1_start_date = '1999-04-01'
epoch1_end_date = '2008-08-01'
mask = (df['origDate'] > epoch1_start_date) & (df['origDate'] <= epoch1_end_date)
mergedEpoch1 = df.loc[mask]

# %%
mergedEpoch1.origDate.min()
# Out:
# Timestamp('1999-05-01 00:00:00')

# %%
mergedEpoch1.origDate.max()
# Out:
# Timestamp('2008-08-01 00:00:00')

# %%
mergedEpoch1.shape
# Out:
# (2278367, 37)

# %%
mergedEpoch1.to_csv('data/FM_Acq2_Perf_FMAC_EPOCH1_loanAge.csv')

# %% [markdown]
# ### EPOCH 2

# %%
#EPOCH 2 - JAN 2009 - JUNE 2013
epoch2_start_date = '2009-01-01'
epoch2_end_date = '2013-06-01'
mask = (df['origDate'] > epoch2_start_date) & (df['origDate'] <= epoch2_end_date)
mergedEpoch2 = merged.loc[mask]

# %%
mergedEpoch2.origDate.min()
# Out:
# Timestamp('2009-02-01 00:00:00')

# %%
mergedEpoch2.origDate.max()
# Out:
# Timestamp('2013-06-01 00:00:00')

# %%
mergedEpoch2.shape
# Out:
# (240948, 37)

# %%
mergedEpoch2.to_csv('data/FM_Acq2_Perf_FMAC_EPOCH2_loanAge.csv')

# %% [markdown]
# ### EPOCH 3

# %%
#EPOCH 3 - SEPT 2013 - MARCH 2019
epoch3_start_date = '2013-10-01'
epoch3_end_date = '2019-03-01'
mask = (df['origDate'] > epoch3_start_date) & (df['origDate'] <= epoch3_end_date)
mergedEpoch3 = merged.loc[mask]

# %%
mergedEpoch3.origDate.min()
# Out:
# Timestamp('2013-11-01 00:00:00')

# %%
mergedEpoch3.origDate.max()
# Out:
# Timestamp('2019-03-01 00:00:00')

# %%
mergedEpoch3.shape
# Out:
# (90581, 37)

# %%
mergedEpoch3.to_csv('data/FM_Acq2_Perf_FMAC_EPOCH3_loanAge.csv')

# %% [markdown]
# ## Create a 2.5% representative sample dataset

# %%
sample2pt5 = df.sample(frac =.025)

# %%
sample2pt5.shape
# Out:
# (66582, 37)

# %%
sample2pt5.to_csv('data/FMAcq2000-19FMac30-sample2pt5_loanAge.csv')

# %% [markdown]
# ## 2.5% Sample Dataset Correlation

# %%
corrSample2pt5 = sample2pt5.corr()

# %%
# Plot the Pearson Correlation reduced matrix
matrix = np.triu(corrSample2pt5)
fig, ax = plt.subplots(figsize=(15,9)) 
ax = sns.heatmap(corrSample2pt5,   mask = matrix, cmap = 'RdYlBu')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title('Pearson Correlation matrix for Fannie 2019 Q1 avg Fico scores dataset')
# Out:
# Text(0.5, 1.0, 'Pearson Correlation matrix for Fannie 2019 Q1 avg Fico scores dataset')

# %% [markdown]
# ## Large Dataset Correlation

# %%
corr = merged.corr()

# Plot the Pearson Correlation reduced matrix
matrix = np.triu(corr)
fig, ax = plt.subplots(figsize=(15,9)) 
ax = sns.heatmap(corr,   mask = matrix, cmap = 'RdYlBu')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title('Pearson Correlation matrix for Fannie 2019 Q1 avg Fico scores dataset')
# Out:
# Text(0.5, 1.0, 'Pearson Correlation matrix for Fannie 2019 Q1 avg Fico scores dataset')

# %%
pp.ProfileReport(merged)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>25 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>10464607 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>2.0 GiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>208.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>13 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>8 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_avgCreditScore"><code>avgCreditScore</code></a> is highly correlated with <a href="#pp_var_worstCreditScore"><code>worstCreditScore</code></a> (ρ = 0.98139) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_bestCreditScore"><code>bestCreditScore</code></a> is highly correlated with <a href="#pp_var_borrCreditScore"><code>borrCreditScore</code></a> (ρ = 0.95187) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_fmacRate"><code>fmacRate</code></a> is highly correlated with <a href="#pp_var_origIntRate"><code>origIntRate</code></a> (ρ = 0.95225) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_fredRate"><code>fredRate</code></a> is highly correlated with <a href="#pp_var_fmacRate"><code>fmacRate</code></a> (ρ = 0.96795) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_mortInsType"><code>mortInsType</code></a> is highly correlated with <a href="#pp_var_pMIperct"><code>pMIperct</code></a> (ρ = 0.91334) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_origCLTV"><code>origCLTV</code></a> is highly correlated with <a href="#pp_var_origLTV"><code>origLTV</code></a> (ρ = 0

# %% [markdown]
# ## Sample25 Python Profile

# %%
pp.ProfileReport(sample2pt5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-7ab3fcafed64> in <module>
# ----> 1 pp.ProfileReport(sample2pt5)
#
# NameError: name 'pp' is not defined
